# %% [markdown]
# # Agenda

# %% [markdown]
# - Part-I
#
#   - Programming Paradigms.
#
#   - What is OOP?
#
#   - Why do we need OOP?
#
#   - Terminology and examples
#
#     - Class, instance, objects, attributes, methods

# %% [markdown]
# - Part - II
#
#  - Classes and Instances
#
#  - Class Variables
#
#  - Inheritance

# %% [markdown]
# - Part - III
#
#   - Creating objects
#
#   - Creating class variables
#
#   - Inheritance

# %% [markdown]
# # Part-I

# %% [markdown]
# ## Programming Styles (Paradigms)
#
# * <b>IMPERATIVE</b> in which the programmer instructs the machine how to change its state,
#   * <b>procedural</b> which groups instructions into procedures,
#   * <b>object-oriented</b> which groups instructions with the part of the state they operate on,
# * <b>DECLARATIVE</b> in which the programmer merely declares properties of the desired result, but not how to compute it
#   * <b>functional</b> in which the desired result is declared as the value of a series of function applications,
#   * <b>logic</b> in which the desired result is declared as the answer to a question about a system of facts and rules,
#   * <b>mathematical</b> in which the desired result is declared as the solution of an optimization problem
#   * <b>reactive</b> in which the desired result is declared with data streams and the propagation of change
#
# -[Programming Paradigms](https://www.youtube.com/watch?v=Wt4FPjkCNaU&ab_channel=Craig%27n%27Dave)
#
# - [A Short Video on Imperative and Declarative programming](https://www.youtube.com/watch?v=yOBBkIJBEL8)

# %% [markdown]
# ## OOP: Object Oriented Programming

# %% [markdown]
# __What is OOP__?
#
#
# Object-oriented programming (OOP) is a programming paradigm based on the concept of "objects", which contain
# * data *in the form of fields (often known as attributes or properties)* and
# * code *in the form of procedures (often known as methods)*. </it>

# %% [markdown]
# __Why OOP?__
#
# - Each object is on its own a program
#
# - Creates boundries
#
# - Ready to use and don't need to understand what is going on inside of an object.
#
# - Organizes the code into logical pieces.

# %% [markdown]
# __Definitions__
# * <b>Class </b>: A template
# * <b>Method (or Message) </b>:  A defined capability of a class
# * <b>Field (or Attribute) </b>: A bit of data in a class
# * <b>Object (or Instance) </b>: A particular instance of a class

# %% [markdown]
# #### Example-1
#
# Class ---> Chair
#
# Object ---> A particular chair
#
# [Different Chairs](https://www.google.com/search?q=chair+images&oq=chair+images&aqs=chrome..69i57j0l9.1845j1j7&sourceid=chrome&ie=UTF-8)
#
# Possible Attributes of a general chair:
# - Height
# - Length
# - Width
# - number of legs
# - color
# - with resting hands or not.
#
# Possible functions of a chair:
# - Adjust height
# - Lean backward
# - Tilt backward
# - Rock
# - fold/unfold

# %% [markdown]
# #### Example 2
# Class = Tree
#
# Object (Instance of a Tree class) ---> A pine tree
#
# [Tree Images](https://www.google.com/search?q=tree+images&sxsrf=ALeKk03oAU2blx0v91nLrOwMrFq81l1ZEw:1618343497847&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjH4cCq__vvAhUpKFkFHa7hAzEQ_AUoAXoECAEQAw&biw=1920&bih=864)
#
# Possible attributes of a tree:
# - kind
# - height
# - width
# - age
# - indoor/ourdoor
# - fruit/no fruit
#
# Possible functions (actions) a general tree can execute:
#
# - grow height
# - drop leaves
# - tilt towards sun
# - grow seeds

# %% [markdown]
# ### Python & Objects

# %%
# In Python, we have several classes, e.g. string, float, integer, list, dict, etc
# By writing 
x = 'UMBC'
# We actually create an instance.
type(x)
# Out:
# str

# %%
# We can learn the available functions
# the ones starting and ending with "__" are "internal use" 
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
y = 3
type(y)
# Out:
# int

# %%
dir(y)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# # Part - II

# %% [markdown]
# ## Syntax and Construction

# %%
## Let's see the syntax for creating a class 
## Syntax
class Student:
  pass

# %%
## Create 2 Student Objects
student1 = Student()
student2 = Student()

# %%
## Show that they are stored in different places
print(student1)
print(student2)
# Out:
# <__main__.Student object at 0x7fdfe85180d0>
# <__main__.Student object at 0x7fdfe8518cd0>

# %% [markdown]
# * We can create lots of objects - the class is the template for the object
# * We can store each distinct object in its own variable
# * Hence we get multiple instances of the same class
# * Each instance has its own copy of the instance variables (and we change those variables separetely for each instance)

# %%
## Each Student will have a name
student1.name = 'Monica'
student2.name = 'Scarlett'

# %%
## let's see the student names are assigned
print(student1.name)
print(student2.name)
# Out:
# Monica
# Scarlett

# %%
# let's create another Student object
student3 = Student()

# %%
### This will fail because ..
student3.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8830dbb748f1> in <module>()
#       1 ### This will fail because ..
# ----> 2 student3.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
## let's add student id,
## campus, first semester and program to our construction.


class Student:
  ## We use a constructor method to create a student
  def __init__(self, name, id):
    self.name = name
    self.id = id

# %%
## let's define student1 and student2 again.
student1 = Student(name = 'Monica', id = 20210413547)

student2 = Student('Scarlett', 20210413550)

student3 = Student('Charlize', 20210413551)

# %%
student1.name
# Out:
# 'Monica'

# %%
class Student:
  ## We use a constructor method to create a student
  def __init__(self, first, last, id, campus, program, enroll_semester):
    self.first = first
    self.last = last
    self.id = id
    self.campus = campus
    self.program = program
    self.enroll_semester = enroll_semester

# %%
## Create new students
student1 = Student(first = 'Monica',
                   last = 'Bellucci',
                   id = 20210413557, 
                   campus = 'Shady Grove', 
                   program = 'Masters',
                   enroll_semester = 'Fall 2021' )

# %%
student2 = Student('Scarlett',
                   'Johansson',
                   20210413600,
                   'Main',
                   'Certificate',
                   'Spring 2022')

# %%
student2.campus = 'Shady Grove'

# %%
student2.last = 'Simsek'

student2.last
# Out:
# 'Simsek'

# %%
student1.campus
# Out:
# 'Shady Grove'

# %% [markdown]
# ## Methods and Attributes and Defaulters

# %%
## let's create a function (method) that calculates the 
## total number of credits based on whether a student is a Masters/Certificate student

class Student:
  def __init__(self, first, last, id, campus, program, enroll_semester):
    self.first = first
    self.last = last
    self.id = id
    self.campus = campus
    self.program = program
    self.enroll_semester = enroll_semester

## Create total_credits method here
  def total_credits(self):
    if self.program == 'Masters':
      return 30
    elif self.program =='Certificate':
      return  12

## Create remaining_credits method here
## Explain what "num_courses = 0" does below
  def remaining_credits(self, num_courses = 0):
    return self.total_credits() - num_courses * 3

# %% [markdown]
# <code> num_courses = 0 </code> in the above cell is a <b>defaulter</b>. <br>
# The primary purpose of the defaulter is to set up some instance variables to have the proper initial values when the object is created, run without giving an error message even if they are not defined by the user while creating an object

# %%
## Now let's create a student again
student1 = Student('Monica', 
                   'Bellucci', 
                   '20030001',
                   'Shady Grove',
                   'Certificate', 
                   'Fall 2021')

## call the total_credits method
print(student1.program)
student1.total_credits()
# Out:
# Certificate
# 12

# %%
student1.remaining_credits()
# Out:
# 12

# %%
student1.remaining_credits(2)
# Out:
# 6

# %%
# Let's define the number of courses taken by student1
student1.num_courses = 3

# %%
# Let's check the remaining_credits
student1.remaining_credits()
# Out:
# 12

# %% [markdown]
# This wasn't what we expected. What went wrong??
# See below

# %%
class Student:
  def __init__(self, first, last, id, campus, program, enroll_semester='Fall 2021', num_courses = 0):
    self.first = first
    self.last = last
    self.id = id
    self.campus = campus
    self.program = program
    self.enroll_semester = enroll_semester
    self.num_courses = int(num_courses)

## Create total_credits method here
  def total_credits(self):
    if self.program == 'Masters':
      return 30
    elif self.program =='Certificate':
      return  12

## Create remaining_credits method here
## Explain what "num_courses = 0" does below
  def remaining_credits(self):
    return self.total_credits() - self.num_courses * 3

# %%
student1 = Student('Monica', 
                   'Bellucci', 
                   '20030001',
                   'Shady Grove',
                   'Certificate')

# %%
student1.remaining_credits()
# Out:
# 12

# %%
student1.num_courses = 3

# %%
student1.remaining_credits()
# Out:
# 3

# %% [markdown]
# ## Class Variables

# %%
class Student:
  ## class variable
  tuition = 1000
    
  def __init__(self, first, last, id, campus, program, enroll_semester):
    self.first = first
    self.last = last
    self.id = id
    self.campus = campus
    self.program = program
    self.enroll_semester = enroll_semester

## Create total_credits method here
  def total_credits(self):
    if self.program == 'Masters':
      return 30
    elif self.program =='Certificate':
      return  12

## define total_tuition method here
  def total_tuition(self):
      return self.tuition * self.total_credits()

# %%
student1 = Student('Monica',
                   'Bellucci', 
                   '20030001',
                   'Shady Grove',
                  'Certificate', 
                   'Fall 2020')

student2 = Student('Scarlett',
                   'Johansson', 
                   '20210413605', 
                   'Main',
                   'Masters', 
                   'Spring 2019')

print(student1.total_tuition())
# Out:
# 12000

# %%
student2.total_tuition()
# Out:
# 30000

# %%
### instance variables vs class variables

# %%
student1.tuition
# Out:
# 1000

# %%
student2.tuition
# Out:
# 1000

# %%
### let's change student1's "instance" variable
student1.tuition = 500

# %%
student2.tuition
# Out:
# 1000

# %%
### let's change "class" variable
## but observe what will happen to student1's tuition
Student.tuition = 250

# %%
student1.tuition
# Out:
# 500

# %%
student2.tuition
# Out:
# 250

# %%
student1 = Student('Monica', 'Bellucci', 
                   '20030001',
                   'Main Campus',
                  'Certificate', 'Fall 2021')

student2 = Student('Scarlett', 'Johansson', '20210413605', 'Main', 'Masters', 'Spring 2022')

print(student1.total_tuition())
print(student2.total_tuition())
# Out:
# 3000
# 7500

# %%
print(student1.total_tuition())
print(student2.total_tuition())

# %%
## let's say student1's tuition is 600
## What would happen if we change it?

student1.tuition = 600

print(student1.total_tuition())
print(student2.total_tuition())
# Out:
# 7200
# 7500

# %%
## how about if we create a new student? 
## Have the tuition updated?
student3 = Student('Mike', 'Oliver', '20210413630', 'Main', 'Certificate', 'Fall 2021')

# %%
student3.tuition
# Out:
# 250

# %%
## dir returns attributes and methods related to an object
dir(student1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'campus',
#  'enroll_semester',
#  'first',
#  'id',
#  'last',
#  'program',
#  'total_credits',
#  'total_tuition',
#  'tuition']

# %% [markdown]
# ## Inheritence
# * When we make a new class - we can reuse an existing class and **inherit** all the capabilities of an existing class and then add our own little bit to make our new class
# * Another form of store and reuse
# * Write once - reuse many times
# * The new class (child) has all the capabilities of the old class (parent) - and then some more

# %%
## Inheritence syntax

class Student:
  tuition = 1000
  def __init__(self, 
               name,
               id,
               campus,
               first_semester,
               program):
    self.name = name
    self.id = id
    self.campus = campus
    self.firs_semester = first_semester
    self.program = program

  def total_credits(self):
    if self.program == 'Masters':
      return 30
    elif self.program == 'Certificate':      
      return 12
    else: 
      return 60
  def total_tuition(self):
    return self.tuition * self.total_credits()

class Undergraduate(Student):
  pass

# %%
## we can define undergraduate now.
undergrad = Undergraduate('Ryan Reynolds', 
                   '19010001',
                   'Shady Grove',
                   'Spring 2019',
                   'UG')

# %%
undergrad.name
# Out:
# 'Ryan Reynolds'

# %%
undergrad.tuition
# Out:
# 1000

# %%
undergrad.total_tuition()
# Out:
# 60000

# %%
## check help function to understand the structure of the inheritance.
help(undergrad)
# Out:
# Help on Undergraduate in module __main__ object:
#
# class Undergraduate(Student)
#  |  Undergraduate(name, id, campus, first_semester, program)
#  |
#  |  Method resolution order:
#  |      Undergraduate
#  |      Student
#  |      builtins.object
#  |
#  |  Methods inherited from Student:
#  |
#  |  __init__(self, name, id, campus, first_semester, program)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  total_credits(self)
#  |
#  |  total_tuition(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Student:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Student:
#  |
#  |  tuition = 1000

# %%
## note that we can use method total_tuition from an undergrad object

# %%
class Undergraduate(Student):
  tuition = 2000
  pass

# %%
undergrad = Undergraduate('Ryan Reynolds', 
                   '19010001',
                   'Shady Grove',
                   'Spring 2019', 'UG')

undergrad.total_tuition()
# Out:
# 120000

# %%
student3 = Student('Scarlett Johansson', 
                   '19010001',
                   'Shady Grove',
                   'Spring 2019',
                   'Masters')

student3.total_tuition()
# Out:
# 30000

# %% [markdown]
# #### Decorators
# * A decorator is any callable Python object that is used to modify a function, method or class definition.
# * A decorator is passed the original object being defined and returns a modified object, which is then bound to the name in the definition.
# * Decorators are defined with the @ symbol

# %%
def smart_divide(func):
    def inner(a, b):
        print("I am going to divide", a, "by", b)
        if b == 0:
            print("Mi dispiace. a/0 is undefined")
            return
        return func(a, b)
    return inner

@smart_divide
def divide(a, b):
    print(a/b)

# %%
divide(2,5)
# Out:
# I am going to divide 2 by 5
# 0.4

# %%
divide(2,0)
# Out:
# I am going to divide 2 by 0
# Mi dispiace. a/0 is undefined

# %% [markdown]
# We can use decorators in classes as well. However there are some special decorators, e.g.  <br>
# * <code>@property</code> is used to convert the attribute access to method access
# * <code>@staticmethod</code> uses the value which is defined in main program (i.e. outside the class)
# * <code>classmethod</code>  uses class variable. <br>
# while the regular
# <code>method </code> uses the instance variable

# %%
# Let's see what will happen here
x = 20

class Add(object):
    x = 9  # class variable

    def __init__(self, x):
        self.x = x  # instance variable

    def addMethod(self, y):
        print("method:", self.x + y)

    @classmethod
    def addClass(self, y):
        print("classmethod:", self.x + y)

    @staticmethod
    def addStatic(y):
        print("staticmethod:", x + y)



def main():
    # method
    m  = Add(x=4)
    m.addMethod(10)  

    # classmethod
    c = Add(4)
    c.addClass(10) 

    s = Add(4)
    s.addStatic(10)  # staticmethod : 30

if __name__ == '__main__':
    main()
# Out:
# method: 14
# classmethod: 19
# staticmethod: 30

# %%
## using constructor with subclasses
class Student:
  tuition = 1000
  def __init__(self, 
               name,
               id,
               campus,
               first_semester,
               program):
    self.name = name
    self.id = id
    self.campus = campus
    self.firs_semester = first_semester
    self.program = program

  def total_credits(self):
    if self.program == 'Masters':
      return 30
    elif self.program == 'Certificate':
      return 12

  @property
  def get_email(self):
    return self.id + '@umbc.edu'

  def total_tuition(self):
    return self.tuition * self.total_credits()
  
  @staticmethod
  def credits_taken(num_courses = 5):
    return 'number of credits taken {}'.format(num_courses*3)

class Undergraduate(Student):
  tuition = 2000
  ## constructor method
  def __init__(self, name, id, campus, first_semester, program, high_school=''):
    super().__init__(name, id, campus, first_semester, program)
    self.high_school = high_school

# %%
student5 = Student(name = 'Monica Bellucci',
                         id =  'MX1012', 
                         campus =  'Main',
                          program = 'Certificate', 
                          first_semester = 'Fall 2020')

# %%
student6 = Undergraduate(name = 'Monica Bellucci',
                         id =  'MX1012', 
                         campus =  'Main',
                          program = 'Certificate', 
                          first_semester = 'Fall 2020',
                          high_school='Wyngate HS')

# %%
student6.high_school
# Out:
# 'Wyngate HS'

# %%
student7 = Undergraduate(name = 'Monica Bellucci',
                         id =  'MX1012', 
                         campus =  'Main',
                          program = 'Certificate', 
                          first_semester = 'Fall 2020')

# %%
student5.credits_taken()
# Out:
# 'number of credits taken 15'

# %%
student5.get_email
# Out:
# 'MX1012@umbc.edu'

# %%
# get help and see get_email part
help(Student)
# Out:
# Help on class Student in module __main__:
#
# class Student(builtins.object)
#  |  Student(name, id, campus, first_semester, program)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, id, campus, first_semester, program)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  total_credits(self)
#  |
#  |  total_tuition(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  credits_taken(num_courses=5)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  get_email
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  tuition = 1000

# %% [markdown]
# ### Object Creation and Destruction
# If you are working with long arrays/matrices which won't be used in the other parts of the code, then please delete them to save some memory. <br>
#
# <code> def \__del__(self): </code> is a destructor method which is called as soon as all references of the object are deleted i.e when an object is garbage collected.

# %%
class SimpleCounter:
   x = 0

   def __init__(self):
     print('I am starting counting')

   def countme(self) :
     self.x = self.x + 1
     print('Count #',self.x)

   def __del__(self):
     print('I am deleting the counter', self.x)

# %%
x = SimpleCounter()
x.countme()
x.countme()
# Out:
# I am starting counting
# Count # 1
# Count # 2

# %%
x = 2
# Out:
# I am deleting the counter 2

# %% [markdown]
# ## Resources

# %% [markdown]
# [Py4e - OOP](https://www.py4e.com/lessons/Objects#)
#
# [Python OOP Tutorials](https://www.youtube.com/playlist?list=PL-osiE80TeTsqhIuOqKhwlXsIBIdSeYtc)
#
# [Imperative vs Declarative Programming](https://www.youtube.com/watch?v=yOBBkIJBEL8&ab_channel=TadasPetra)
#
# [Python OPP Exercises](https://pynative.com/python-object-oriented-programming-oop-exercise/)
