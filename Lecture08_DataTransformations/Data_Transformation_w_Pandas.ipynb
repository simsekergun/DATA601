# %% [markdown]
# <a href="https://colab.research.google.com/github/simsekergun/DATA601/blob/main/Lecture08_DataTransformations/Data_Transformation_w_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
flights = pd.read_csv('https://raw.githubusercontent.com/mguner/teaching/main/datasets/nyc_flights/nyc_flights.csv')

# %% [markdown]
# - year, month, day Date of departure.
# - dep_time, arr_time Actual departure and arrival times (format HHMM or HMM), local tz.
# - sched_dep_time, sched_arr_time Scheduled departure and arrival times (format HHMM or HMM),
# - local tz.
# - dep_delay, arr_delay Departure and arrival delays, in minutes. Negative times represent early departures/arrivals.
# - carrier Two letter carrier abbreviation.
# - flight Flight number.
# - tailnum identification number of an aircraft painted on its tail
# - origin, dest Origin and destination.
# - air_time Amount of time spent in the air, in minutes.
# - distance Distance between airports, in miles.
# - hour, minute Time of scheduled departure broken into hour and minutes.
# - time_hour Scheduled date and hour of the flight as a POSIXct date.

# %%
## let's take a look at the first 5 rows.
flights.head(3)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z

# %%
flights.tail(2)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute             time_hour
# 336774       NaN       419    11      59  2013-09-30T15:00:00Z
# 336775       NaN       431     8      40  2013-09-30T12:00:00Z

# %%
## check info for the dataframe
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
#  16  hour            336776 non-null  int64
#  17  minute          336776 non-null  int64
#  18  time_hour       336776 non-null  object
# dtypes: float64(5), int64(9), object(5)
# memory usage: 48.8+ MB

# %%
flights.shape
# Out:
# (336776, 19)

# %%
flights.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# min       -43.000000       1.000000        1.000000     -86.000000
# 25%        -5.000000    1104.000000     1124.000000     -17.000000
# 50%        -2.000000    1535.000000     1556.000000      -5.000000
# 75%        11.000000    1940.000000     1945.000000      14.000000
# max      1301.000000    2400.000000     2359.000000    1272.000000
#
#               flight       air_time       distance           hour  \
# count  336776.000000  327346.000000  336776.000000  336776.000000
# mean     1971.923620     150.686460    1039.912604      13.180247
# std      1632.471938      93.688305     733.233033       4.661316
# min         1.000000      20.000000      17.000000       1.000000
# 25%       553.000000      82.000000     502.000000       9.000000
# 50%      1496.000000     129.000000     872.000000      13.000000
# 75%      3465.000000     192.000000    1389.000000      17.000000
# max      8500.000000     695.000000    4983.000000      23.000000
#
#               minute
# count  336776.000000
# mean       26.230100
# std        19.300846
# min         0.000000
# 25%         8.000000
# 50%        29.000000
# 75%        44.000000
# max        59.000000

# %%
## pick all the flights with 'UA' as the carrier
flights[flights.carrier == 'UA']
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336723  2013      9   30    2052.0            2059       -7.0    2315.0
# 336728  2013      9   30    2055.0            2059       -4.0    2158.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# 12                 917        7.0      UA     194  N29129    JFK  LAX
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336723            2358      -43.0      UA    1416  N68453    EWR  MCO
# 336728            2211      -13.0      UA    1066  N16701    EWR  BOS
# 336737            2354      -25.0      UA     475  N477UA    EWR  IAH
# 336755            2308      -23.0      UA     523  N813UA    EWR  BOS
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute             time_hour
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 5          150.0       719     5      58  2013-01-01T10:00:00Z
# 12         345.0      2475     6       0  2013-01-01T11:00:00Z
# 13         361.0      2565     6       0  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336723     123.0       937    20      59  2013-10-01T00:00:00Z
# 336728      40.0       200    20      59  2013-10-01T00:00:00Z
# 336737     175.0      1400    21       6  2013-10-01T01:00:00Z
# 336755      37.0       200    21      56  2013-10-01T01:00:00Z
# 336762     318.0      2565    21      13  2013-10-01T01:00:00Z
#
# [58665 rows x 19 columns]

# %%
flights[flights.carrier == 'UA'].drop('carrier', axis=1)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336723  2013      9   30    2052.0            2059       -7.0    2315.0
# 336728  2013      9   30    2055.0            2059       -4.0    2158.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay  flight tailnum origin dest  air_time  \
# 0                  819       11.0    1545  N14228    EWR  IAH     227.0
# 1                  830       20.0    1714  N24211    LGA  IAH     227.0
# 5                  728       12.0    1696  N39463    EWR  ORD     150.0
# 12                 917        7.0     194  N29129    JFK  LAX     345.0
# 13                 937      -14.0    1124  N53441    EWR  SFO     361.0
# ...                ...        ...     ...     ...    ...  ...       ...
# 336723            2358      -43.0    1416  N68453    EWR  MCO     123.0
# 336728            2211      -13.0    1066  N16701    EWR  BOS      40.0
# 336737            2354      -25.0     475  N477UA    EWR  IAH     175.0
# 336755            2308      -23.0     523  N813UA    EWR  BOS      37.0
# 336762              30       42.0     471  N578UA    EWR  SFO     318.0
#
#         distance  hour  minute             time_hour
# 0           1400     5      15  2013-01-01T10:00:00Z
# 1           1416     5      29  2013-01-01T10:00:00Z
# 5            719     5      58  2013-01-01T10:00:00Z
# 12          2475     6       0  2013-01-01T11:00:00Z
# 13          2565     6       0  2013-01-01T11:00:00Z
# ...          ...   ...     ...                   ...
# 336723       937    20      59  2013-10-01T00:00:00Z
# 336728       200    20      59  2013-10-01T00:00:00Z
# 336737      1400    21       6  2013-10-01T01:00:00Z
# 336755       200    21      56  2013-10-01T01:00:00Z
# 336762      2565    21      13  2013-10-01T01:00:00Z
#
# [58665 rows x 18 columns]

# %%
## check what happens if we just execute the inside code in previous code
trues_falses = (flights.carrier == 'UA').values
trues_falses
# Out:
# array([ True,  True, False, ..., False, False, False])

# %%
## let's talk about Boolean Masking
flights[trues_falses]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336723  2013      9   30    2052.0            2059       -7.0    2315.0
# 336728  2013      9   30    2055.0            2059       -4.0    2158.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# 12                 917        7.0      UA     194  N29129    JFK  LAX
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336723            2358      -43.0      UA    1416  N68453    EWR  MCO
# 336728            2211      -13.0      UA    1066  N16701    EWR  BOS
# 336737            2354      -25.0      UA     475  N477UA    EWR  IAH
# 336755            2308      -23.0      UA     523  N813UA    EWR  BOS
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute             time_hour
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 5          150.0       719     5      58  2013-01-01T10:00:00Z
# 12         345.0      2475     6       0  2013-01-01T11:00:00Z
# 13         361.0      2565     6       0  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336723     123.0       937    20      59  2013-10-01T00:00:00Z
# 336728      40.0       200    20      59  2013-10-01T00:00:00Z
# 336737     175.0      1400    21       6  2013-10-01T01:00:00Z
# 336755      37.0       200    21      56  2013-10-01T01:00:00Z
# 336762     318.0      2565    21      13  2013-10-01T01:00:00Z
#
# [58665 rows x 19 columns]

# %%
flights[trues_falses].arr_delay.min()
# Out:
# -75.0

# %% [markdown]
# - NumPy also implements comparison operators such as < (less than) and > (greater than) as element-wise universal functions.
# - The result of these comparison operators is always an array with a Boolean data type.
#
# [Comparison Operators as ufuncs - DataScienceHandbook](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html#Comparison-Operators-as-ufuncs)

# %% [markdown]
# ![Screen Shot 2021-09-16 at 1.51.45 PM.png](data:image/png;base64,...)

# %% [markdown]
# [Boolean Operators](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html#Boolean-operators)

# %% [markdown]
# operator|function
# -----| -----
# `&` | 'and' operator
# `\|` | 'or' operator
# `\~` | 'not' operator
# `\^` | 'xor' operator

# %% [markdown]
# ![Screen Shot 2021-09-16 at 2.06.07 PM.png](data:image/png;base64,...)

# %%
## Let's combine multiple conditions
## in addition to carrier let's use dep_delay comparison
# df[(cond1) & (cond2)]
flights[(flights.carrier == 'UA') & (flights.dep_delay > 3)]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1       2013      1    1     533.0             529        4.0     850.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 47      2013      1    1     644.0             636        8.0     931.0
# 70      2013      1    1     709.0             700        9.0     852.0
# 85      2013      1    1     732.0             645       47.0    1011.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336631  2013      9   30    1909.0            1901        8.0    2212.0
# 336655  2013      9   30    1935.0            1930        5.0    2230.0
# 336685  2013      9   30    2008.0            1935       33.0    2322.0
# 336714  2013      9   30    2035.0            2029        6.0    2318.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 47                 940       -9.0      UA    1701  N75435    EWR  FLL
# 70                 832       20.0      UA    1092  N26226    LGA  ORD
# 85                 941       30.0      UA    1111  N37456    EWR  MCO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336631            2211        1.0      UA     237  N513UA    EWR  SFO
# 336655            2233       -3.0      UA    1115  N38446    EWR  TPA
# 336685            2242       40.0      UA     208  N816UA    EWR  SEA
# 336714            2337      -19.0      UA    1039  N78524    EWR  AUS
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute             time_hour
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 26         366.0      2586     6       0  2013-01-01T11:00:00Z
# 47         151.0      1065     6      36  2013-01-01T11:00:00Z
# 70         135.0       733     7       0  2013-01-01T12:00:00Z
# 85         145.0       937     6      45  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336631     307.0      2565    19       1  2013-09-30T23:00:00Z
# 336655     132.0       997    19      30  2013-09-30T23:00:00Z
# 336685     339.0      2402    19      35  2013-09-30T23:00:00Z
# 336714     191.0      1504    20      29  2013-10-01T00:00:00Z
# 336762     318.0      2565    21      13  2013-10-01T01:00:00Z
#
# [21562 rows x 19 columns]

# %% [markdown]
# ## Missing Values

# %% [markdown]
# [Missing Values in Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html)

# %%
## let's use .isnull to see how pandas is handling missing values
## also use notnull for a column to find all the observations with valid values 
## in that column

# %%
flights.isnull()
# Out:
#          year  month    day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       False  False  False     False           False      False     False
# 1       False  False  False     False           False      False     False
# 2       False  False  False     False           False      False     False
# 3       False  False  False     False           False      False     False
# 4       False  False  False     False           False      False     False
# ...       ...    ...    ...       ...             ...        ...       ...
# 336771  False  False  False      True           False       True      True
# 336772  False  False  False      True           False       True      True
# 336773  False  False  False      True           False       True      True
# 336774  False  False  False      True           False       True      True
# 336775  False  False  False      True           False       True      True
#
#         sched_arr_time  arr_delay  carrier  flight  tailnum  origin   dest  \
# 0                False      False    False   False    False   False  False
# 1                False      False    False   False    False   False  False
# 2                False      False    False   False    False   False  False
# 3                False      False    False   False    False   False  False
# 4                False      False    False   False    False   False  False
# ...                ...        ...      ...     ...      ...     ...    ...
# 336771           False       True    False   False     True   False  False
# 336772           False       True    False   False     True   False  False
# 336773           False       True    False   False    False   False  False
# 336774           False       True    False   False    False   False  False
# 336775           False       True    False   False    False   False  False
#
#         air_time  distance   hour  minute  time_hour
# 0          False     False  False   False      False
# 1          False     False  False   False      False
# 2          False     False  False   False      False
# 3          False     False  False   False      False
# 4          False     False  False   False      False
# ...          ...       ...    ...     ...        ...
# 336771      True     False  False   False      False
# 336772      True     False  False   False      False
# 336773      True     False  False   False      False
# 336774      True     False  False   False      False
# 336775      True     False  False   False      False
#
# [336776 rows x 19 columns]

# %%
flights.notnull()
# Out:
#         year  month   day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       True   True  True      True            True       True      True
# 1       True   True  True      True            True       True      True
# 2       True   True  True      True            True       True      True
# 3       True   True  True      True            True       True      True
# 4       True   True  True      True            True       True      True
# ...      ...    ...   ...       ...             ...        ...       ...
# 336771  True   True  True     False            True      False     False
# 336772  True   True  True     False            True      False     False
# 336773  True   True  True     False            True      False     False
# 336774  True   True  True     False            True      False     False
# 336775  True   True  True     False            True      False     False
#
#         sched_arr_time  arr_delay  carrier  flight  tailnum  origin  dest  \
# 0                 True       True     True    True     True    True  True
# 1                 True       True     True    True     True    True  True
# 2                 True       True     True    True     True    True  True
# 3                 True       True     True    True     True    True  True
# 4                 True       True     True    True     True    True  True
# ...                ...        ...      ...     ...      ...     ...   ...
# 336771            True      False     True    True    False    True  True
# 336772            True      False     True    True    False    True  True
# 336773            True      False     True    True     True    True  True
# 336774            True      False     True    True     True    True  True
# 336775            True      False     True    True     True    True  True
#
#         air_time  distance  hour  minute  time_hour
# 0           True      True  True    True       True
# 1           True      True  True    True       True
# 2           True      True  True    True       True
# 3           True      True  True    True       True
# 4           True      True  True    True       True
# ...          ...       ...   ...     ...        ...
# 336771     False      True  True    True       True
# 336772     False      True  True    True       True
# 336773     False      True  True    True       True
# 336774     False      True  True    True       True
# 336775     False      True  True    True       True
#
# [336776 rows x 19 columns]

# %%
# dropna() will drop all rows in which any null value is present:
flights.dropna()
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336765            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336766               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336767               1      -16.0      B6     486  N346JB    JFK  ROC
# 336768            2358        1.0      B6     718  N565JB    JFK  BOS
# 336769             350      -25.0      B6     745  N516JB    JFK  PSE
#
#         air_time  distance  hour  minute             time_hour
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 2          160.0      1089     5      40  2013-01-01T10:00:00Z
# 3          183.0      1576     5      45  2013-01-01T10:00:00Z
# 4          116.0       762     6       0  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336765      41.0       209    22      45  2013-10-01T02:00:00Z
# 336766      52.0       301    22      50  2013-10-01T02:00:00Z
# 336767      47.0       264    22      46  2013-10-01T02:00:00Z
# 336768      33.0       187    22      55  2013-10-01T02:00:00Z
# 336769     196.0      1617    23      59  2013-10-01T03:00:00Z
#
# [327346 rows x 19 columns]

# %%
# you can drop NA values along a different axis; axis=1 drops all columns containing a null value:
flights.dropna(axis='columns')
# Out:
#         year  month  day  sched_dep_time  sched_arr_time carrier  flight  \
# 0       2013      1    1             515             819      UA    1545
# 1       2013      1    1             529             830      UA    1714
# 2       2013      1    1             540             850      AA    1141
# 3       2013      1    1             545            1022      B6     725
# 4       2013      1    1             600             837      DL     461
# ...      ...    ...  ...             ...             ...     ...     ...
# 336771  2013      9   30            1455            1634      9E    3393
# 336772  2013      9   30            2200            2312      9E    3525
# 336773  2013      9   30            1210            1330      MQ    3461
# 336774  2013      9   30            1159            1344      MQ    3572
# 336775  2013      9   30             840            1020      MQ    3531
#
#        origin dest  distance  hour  minute             time_hour
# 0         EWR  IAH      1400     5      15  2013-01-01T10:00:00Z
# 1         LGA  IAH      1416     5      29  2013-01-01T10:00:00Z
# 2         JFK  MIA      1089     5      40  2013-01-01T10:00:00Z
# 3         JFK  BQN      1576     5      45  2013-01-01T10:00:00Z
# 4         LGA  ATL       762     6       0  2013-01-01T11:00:00Z
# ...       ...  ...       ...   ...     ...                   ...
# 336771    JFK  DCA       213    14      55  2013-09-30T18:00:00Z
# 336772    LGA  SYR       198    22       0  2013-10-01T02:00:00Z
# 336773    LGA  BNA       764    12      10  2013-09-30T16:00:00Z
# 336774    LGA  CLE       419    11      59  2013-09-30T15:00:00Z
# 336775    LGA  RDU       431     8      40  2013-09-30T12:00:00Z
#
# [336776 rows x 13 columns]

# %%
# For finer-grained control, the thresh parameter lets you specify 
# a minimum number of non-null values for the row/column to be kept

# %%
#Sometimes rather than dropping NA values, you'd rather replace them with a valid value. 
# This value might be a single number like zero 
#   ==> e.g., flights.fillna(0)
# or it might be some sort of imputation or interpolation from the good values. 
# # forward-fill
# # flights.fillna(method='ffill')
# # backward-fill
# # flights.fillna(method='bfill')

# not very useful in this case, so let's skip

# %% [markdown]
# ## index of a dataframe

# %% [markdown]
# [Pandas - Documentation - Indexing and selecting Data](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %% [markdown]
# __Why indexing data?__
#
# - identifying observations
# - Allows intuitive subseting

# %% [markdown]
# __.loc__
# - Label based
# - will raise error if the item is not found.
#
# __.iloc__
#
# - Integer position based
# - will raise an error if the indexer is out-of-bounds. (slicer allow this)

# %% [markdown]
# __Examples__

# %%
## we can also use loc and iloc to subset columns
flights.loc[np.arange(6), ['carrier', 'dep_delay']]
# Out:
#   carrier  dep_delay
# 0      UA        2.0
# 1      UA        4.0
# 2      AA        2.0
# 3      B6       -1.0
# 4      DL       -6.0
# 5      UA       -4.0

# %%
## iloc version
flights.iloc[np.arange(6), [9, 5]]
# Out:
#   carrier  dep_delay
# 0      UA        2.0
# 1      UA        4.0
# 2      AA        2.0
# 3      B6       -1.0
# 4      DL       -6.0
# 5      UA       -4.0

# %%
## note that iloc would give an error
#flights.iloc[:, ['carrier', 'dep_delay']]

# %% [markdown]
# ## Sorting Values

# %%
## let's sort dep_delay column
# flights.dep_delay.sort_values(ascending = False)
flights['dep_delay'].sort_values(ascending = False)
# flights['dep_delay'].sort_values()
# Out:
# 7072      1301.0
# 235778    1137.0
# 8239      1126.0
# 327043    1014.0
# 270376    1005.0
#            ...
# 336771       NaN
# 336772       NaN
# 336773       NaN
# 336774       NaN
# 336775       NaN
# Name: dep_delay, Length: 336776, dtype: float64

# %%
## Use ascending parameter to reverse the ordering 
flights.dep_delay.sort_values()
# Out:
# 89673    -43.0
# 113633   -33.0
# 64501    -32.0
# 9619     -30.0
# 24915    -27.0
#           ...
# 336771     NaN
# 336772     NaN
# 336773     NaN
# 336774     NaN
# 336775     NaN
# Name: dep_delay, Length: 336776, dtype: float64

# %% [markdown]
# ## Counting Values

# %%
## How many times a carrier make flights.
flights.carrier.value_counts()
# Out:
# UA    58665
# B6    54635
# EV    54173
# DL    48110
# AA    32729
# MQ    26397
# US    20536
# 9E    18460
# WN    12275
# VX     5162
# FL     3260
# AS      714
# F9      685
# YV      601
# HA      342
# OO       32
# Name: carrier, dtype: int64

# %%
## We can use "dropna" to count missing values
flights.dep_delay.value_counts(dropna = True)
# Out:
# -5.0      24821
# -4.0      24619
# -3.0      24218
# -2.0      21516
# -6.0      20701
#           ...
#  545.0        1
#  443.0        1
#  800.0        1
#  911.0        1
#  422.0        1
# Name: dep_delay, Length: 527, dtype: int64

# %%
flights.dep_delay.value_counts(dropna = True, bins = 15)
# Out:
# (-44.345, 46.6]     293915
# (46.6, 136.2]        27034
# (136.2, 225.8]        5653
# (225.8, 315.4]        1433
# (315.4, 405.0]         361
# (405.0, 494.6]          64
# (494.6, 584.2]          17
# (763.4, 853.0]          15
# (584.2, 673.8]          12
# (673.8, 763.4]           6
# (853.0, 942.6]           5
# (942.6, 1032.2]          3
# (1121.8, 1211.4]         2
# (1211.4, 1301.0]         1
# (1032.2, 1121.8]         0
# Name: dep_delay, dtype: int64

# %%
# note that the output will be ordered based on counts
edges = [-100, -80, -10,-5, 0, 30, 60, 120, 240, 720]
flights.dep_delay.value_counts(dropna = True, bins = edges)
# Out:
# (-5.0, 0.0]          105680
# (-10.0, -5.0]         81940
# (0.0, 30.0]           80141
# (30.0, 60.0]          21710
# (60.0, 120.0]         16858
# (-80.0, -10.0]        12469
# (120.0, 240.0]         8199
# (240.0, 720.0]         1495
# (-100.001, -80.0]         0
# Name: dep_delay, dtype: int64

# %%
flights.dep_delay.value_counts(dropna = True).loc[lambda x : x>4].hist(bins = 10)

# %%
## we can directly use nunique and unique to count unique values in a column
no_of_cars = flights.carrier.nunique()

# %%
flights.carrier.unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %% [markdown]
# ## Summary Information: Revisited

# %%
## let's see the basic summary statistics for ['dep_delay', 'arr_time', 'arr_delay']
flights[['dep_delay', 'arr_time', 'arr_delay']].describe()
# Out:
#            dep_delay       arr_time      arr_delay
# count  328521.000000  328063.000000  327346.000000
# mean       12.639070    1502.054999       6.895377
# std        40.210061     533.264132      44.633292
# min       -43.000000       1.000000     -86.000000
# 25%        -5.000000    1104.000000     -17.000000
# 50%        -2.000000    1535.000000      -5.000000
# 75%        11.000000    1940.000000      14.000000
# max      1301.000000    2400.000000    1272.000000

# %%
## Let's visualize this
arr_delay = flights.arr_delay.dropna().values
plt.figure(figsize = (15, 5))
plt.boxplot(arr_delay, vert = False)
plt.show()

# %%
arr_delay = flights.arr_delay.dropna().values
arr_delay
# Out:
# array([ 11.,  20.,  33., ..., -16.,   1., -25.])

# %%
plt.figure(figsize = (15, 5))
plt.hist(arr_delay,bins=[0, 5, 10, 20, 30, 50, 75, 100, 120, 150, 200])
plt.show()

# %%
# let's plot sorted values of arr_delay between x = 0 (where min arr_delay occurs) and x = 100 (where max arr_delay happens)
x = np.arange(len(arr_delay)) / len(arr_delay)*100
plt.figure(figsize = (15, 5))
plt.plot(x,np.sort(arr_delay))
plt.show()

# %%
## we can also use .quantile method to find a value of the quantile
flights.arr_delay.quantile(0.5)
# Out:
# -5.0

# %%
flights.arr_delay.quantile(0.80)
# Out:
# 21.0

# %%
## We can use other summary statistics
## max
flights.arr_delay.max()
# Out:
# 1272.0

# %%
## min
flights.arr_delay.min()
# Out:
# -86.0

# %%
## std

flights.arr_delay.std()
# Out:
# 44.63329169019526

# %%
## variance
flights.arr_delay.var()
# Out:
# 1992.130727102053

# %% [markdown]
# ## Group_By method: Basics

# %%
monthly_mean_dep_delays = flights.groupby(['month']).dep_delay.mean()
monthly_mean_dep_delays
# Out:
# month
# 1     10.036665
# 2     10.816843
# 3     13.227076
# 4     13.938038
# 5     12.986859
# 6     20.846332
# 7     21.727787
# 8     12.611040
# 9      6.722476
# 10     6.243988
# 11     5.435362
# 12    16.576688
# Name: dep_delay, dtype: float64

# %%
plt.figure(figsize = (15, 5))
plt.plot(monthly_mean_dep_delays)
plt.show()

# %%
## Let's group the flights data with day column
## and take a look at total delays happened for each day
daily_total_dep_delays = flights.groupby(['day']).dep_delay.sum()
daily_total_dep_delays
# Out:
# day
# 1     152923.0
# 2     149032.0
# 3     120027.0
# 4      63553.0
# 5      83151.0
# 6      75236.0
# 7     152956.0
# 8     225224.0
# 9     150313.0
# 10    195669.0
# 11    173956.0
# 12    161370.0
# 13    147408.0
# 14     97546.0
# 15     77001.0
# 16     94331.0
# 17    148707.0
# 18    166157.0
# 19    165203.0
# 20     94231.0
# 21    100697.0
# 22    206600.0
# 23    183579.0
# 24    164416.0
# 25    160238.0
# 26    104908.0
# 27    131389.0
# 28    164123.0
# 29     84107.0
# 30    100568.0
# 31     57581.0
# Name: dep_delay, dtype: float64

# %%
plt.figure(figsize = (15, 5))
plt.plot(daily_total_dep_delays)
plt.show()

# %% [markdown]
# __Under the hood__ <br>

# %% [markdown]
# ![Screen Shot 2021-09-22 at 11.43.40 AM.png](data:image/png;base64,...)

# %% [markdown]
# [Figure Source](https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html#Split,-apply,-combine)

# %%
## Group Flights by destination and
## take a look at the average delay for each day of the month
delays_destination = flights.groupby('dest').dep_delay.mean()
delays_destination
# Out:
# dest
# ABQ    13.740157
# ACK     6.456604
# ALB    23.620525
# ANC    12.875000
# ATL    12.509824
#          ...
# TPA    12.135007
# TUL    34.906355
# TVC    22.083333
# TYS    28.493955
# XNA     6.464886
# Name: dep_delay, Length: 105, dtype: float64

# %%
## Let's visualize this
# change the style if you wish
plt.style.use('seaborn-talk')

# figure size
plt.figure(figsize = (20, 7))

# Histogram
plt.bar(delays_destination.index, delays_destination.values)

# x-label
plt.xlabel('Destination Airport')

# y-label
plt.ylabel('Average Delays')

# x_ticks
plt.xticks(rotation = 90)

# Show
plt.show()

# %%
## let's take a look at the destinations with 
## avg delay is more than 25
delays_destination[delays_destination >25]
# Out:
# dest
# BHM    29.694853
# CAE    35.570093
# DSM    26.232955
# JAC    26.545455
# OKC    30.568807
# TUL    34.906355
# TYS    28.493955
# Name: dep_delay, dtype: float64

# %% [markdown]
# Do you see any pattern?
#
# __BHM__: [Birmingham-AL](https://goo.gl/maps/9UHiEJxrjQCZkbim7)
#
# __CAE__: [Columbia-SC](https://goo.gl/maps/HzF1ZSQyWz4LoxTi6)
#
# __DSM__: [Des Moines - IO](https://goo.gl/maps/3EgkwDpfYKo6Yngv5)
#
# __JAC__: [Jackson - WY](https://goo.gl/maps/CESs8scrCM5GWAda8)
#
# __OKC__: [Oklahoma City - OK](https://goo.gl/maps/DfUEo7r9tV3FEzKq7)
#
# __TUL__: [Tulsa - OK](https://goo.gl/maps/xuArw3CEjHh4zh5R6)
#
# __TYS__: [Knoxville - TN](https://goo.gl/maps/5cyYPi2xZhdiADkDA)

# %% [markdown]
# ## Aggregation

# %% [markdown]
# - I would like to hypothesize that these airports have less air-traffic then some other airports. To be able to see this, I need to group my data with `destinations` and then take the `mean` of `dep_delay` and `count` of `dest`.
#
# - To achieve our goal quickly we can use `aggregate` method.

# %%
## First create a agg_dictionary
agg_dictionary = {'dest': 'count', 'dep_delay': 'mean'}

## use the dictionary we created above in .aggregate method
flights.groupby('dest').aggregate(agg_dictionary)
# Out:
#        dest  dep_delay
# dest
# ABQ     254  13.740157
# ACK     265   6.456604
# ALB     439  23.620525
# ANC       8  12.875000
# ATL   17215  12.509824
# ...     ...        ...
# TPA    7466  12.135007
# TUL     315  34.906355
# TVC     101  22.083333
# TYS     631  28.493955
# XNA    1036   6.464886
#
# [105 rows x 2 columns]

# %% [markdown]
# __Let's check our hypothesis:__

# %%
## store the resulting dataframe above in a variable aggregated_df
aggregated_df = flights.groupby('dest').aggregate(agg_dictionary)

## check the values with destinations with more than 25mins average delay
print(aggregated_df[aggregated_df.dep_delay >25])
# Out:
#       dest  dep_delay
# dest
# BHM    297  29.694853
# CAE    116  35.570093
# DSM    569  26.232955
# JAC     25  26.545455
# OKC    346  30.568807
# TUL    315  34.906355
# TYS    631  28.493955

# %%
## Note that the count is 631 for the TYS 
## see how many other destinations have less than this value
## as their flights count.
aggregated_df[aggregated_df.dest >631].shape
# Out:
# (68, 2)

# %% [markdown]
# 68 of the 105 destinations had more flights from NYC airports than the destinations of those fligths with more than 25 mins average delay_time.

# %% [markdown]
# ### Aggregation and naming columns of the resulting table

# %%
## note that the following code is not working
aggregated_df.sort_values(by = 'dest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-3fcdba5082d6> in <module>()
#       1 ## note that the following code is not working
# ----> 2 aggregated_df.sort_values(by = 'dest')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772
#    1773         if self._is_label_reference(key, axis=axis):
# -> 1774             self._check_label_or_level_ambiguity(key, axis=axis)
#    1775             values = self.xs(key, axis=other_axes[0])._values
#    1776         elif self._is_level_reference(key, axis=axis):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1731                 f"{label_article} {label_type} label, which is ambiguous."
#    1732             )
# -> 1733             raise ValueError(msg)
#    1734
#    1735     @final
#
# ValueError: 'dest' is both an index level and a column label, which is ambiguous.

# %% [markdown]
# Proper way of aggregation

# %%
grouped_by_dest = flights.groupby('dest').agg(
    flight_counts = ('dest', 'count') , 
    delay_mean= ('dep_delay', 'mean') ,
    distance_mean = ('distance', 'mean')
    )
grouped_by_dest
# Out:
#       flight_counts  delay_mean  distance_mean
# dest
# ABQ             254   13.740157    1826.000000
# ACK             265    6.456604     199.000000
# ALB             439   23.620525     143.000000
# ANC               8   12.875000    3370.000000
# ATL           17215   12.509824     757.108220
# ...             ...         ...            ...
# TPA            7466   12.135007    1003.935575
# TUL             315   34.906355    1215.000000
# TVC             101   22.083333     652.386139
# TYS             631   28.493955     638.809826
# XNA            1036    6.464886    1142.505792
#
# [105 rows x 3 columns]

# %% [markdown]
# ### User defined functions

# %% [markdown]
# Finally we can use user-defined functions for aggregation

# %%
# define my_avg_funct
def my_avg_cost(x):
  return x.mean()*20.0

# %%
# let's use my_avg_func instead of 'mean'
grouped_by_dest = flights.groupby('dest').agg(
    flight_counts = ('dest', 'count') , 
    delay_mean= ('dep_delay', 'mean') ,
    average_cost = ('distance', my_avg_cost)
    )
grouped_by_dest
# Out:
#       flight_counts  delay_mean  average_cost
# dest
# ABQ             254   13.740157  36520.000000
# ACK             265    6.456604   3980.000000
# ALB             439   23.620525   2860.000000
# ANC               8   12.875000  67400.000000
# ATL           17215   12.509824  15142.164392
# ...             ...         ...           ...
# TPA            7466   12.135007  20078.711492
# TUL             315   34.906355  24300.000000
# TVC             101   22.083333  13047.722772
# TYS             631   28.493955  12776.196513
# XNA            1036    6.464886  22850.115830
#
# [105 rows x 3 columns]

# %%
## we can also use built-in functions from other libraries
## especially from numpy

# %% [markdown]
# ## Grouping by multiple variables

# %%
multiple_grouped = flights.groupby(['origin', 'dest']).dep_delay.mean()

multiple_grouped
# Out:
# origin  dest
# EWR     ALB     23.620525
#         ANC     12.875000
#         ATL     15.501738
#         AUS     11.508863
#         AVL      8.616601
#                   ...
# LGA     SYR     19.110701
#         TPA     11.287324
#         TVC     23.410959
#         TYS     12.705660
#         XNA      5.933793
# Name: dep_delay, Length: 224, dtype: float64

# %% [markdown]
# Now we can access a group by usign its multiple index:

# %%
multiple_grouped[('JFK', 'BOS')]
# Out:
# 11.694953335637747

# %% [markdown]
# ## Filtering
#
# A filtering operation allows you to drop data based on the group properties.

# %%
## define a function that checks whether for a given group the mean delay time is 
## more than 25 mins
def my_delay_funct(group):
  return group.dep_delay.mean() > 25

# %%
## use my_delay_funct to filter the original dataframe
filtered_by_delay = flights.groupby(['dest']).filter(my_delay_funct)
filtered_by_delay
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 152     2013      1    1     848.0             851       -3.0    1155.0
# 733     2013      1    1    1952.0            1930       22.0    2358.0
# 742     2013      1    1    2000.0            1930       30.0    2255.0
# 754     2013      1    1    2016.0            1930       46.0       NaN
# 803     2013      1    1    2119.0            1930      109.0    2358.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336659  2013      9   30    1939.0            1950      -11.0    2112.0
# 336677  2013      9   30    2000.0            2007       -7.0    2142.0
# 336707  2013      9   30    2031.0            2040       -9.0    2228.0
# 336731  2013      9   30    2059.0            2003       56.0    2311.0
# 336734  2013      9   30    2104.0            2019       45.0    2304.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 152               1136       19.0      UA    1741  N27724    EWR  JAC
# 733               2207        NaN      EV    4333  N11194    EWR  TUL
# 742               2140       75.0      EV    4361  N12567    EWR  TYS
# 754               2220        NaN      EV    4204  N14168    EWR  OKC
# 803               2136      142.0      EV    4543  N13123    EWR  DSM
# ...                ...        ...     ...     ...     ...    ...  ...
# 336659            2141      -29.0      EV    5038  N713EV    LGA  BHM
# 336677            2202      -20.0      EV    4543  N11194    EWR  DSM
# 336707            2300      -32.0      9E    4033  N8924B    LGA  TYS
# 336731            2237       34.0      EV    4204  N11127    EWR  OKC
# 336734            2240       24.0      EV    4333  N11109    EWR  TUL
#
#         air_time  distance  hour  minute             time_hour
# 152        275.0      1874     8      51  2013-01-01T13:00:00Z
# 733          NaN      1215    19      30  2013-01-02T00:00:00Z
# 742        138.0       631    19      30  2013-01-02T00:00:00Z
# 754          NaN      1325    19      30  2013-01-02T00:00:00Z
# 803        200.0      1017    19      30  2013-01-02T00:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336659     112.0       866    19      50  2013-09-30T23:00:00Z
# 336677     138.0      1017    20       7  2013-10-01T00:00:00Z
# 336707      86.0       647    20      40  2013-10-01T00:00:00Z
# 336731     166.0      1325    20       3  2013-10-01T00:00:00Z
# 336734     154.0      1215    20      19  2013-10-01T00:00:00Z
#
# [2299 rows x 19 columns]

# %% [markdown]
# Note that this is not equal to getting all flights whose delay time is more than 25 mins.

# %%
# return all the flights with more than 25 mins delay
flights[flights.dep_delay > 25]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 85      2013      1    1     732.0             645       47.0    1011.0
# 96      2013      1    1     749.0             710       39.0     939.0
# 119     2013      1    1     811.0             630      101.0    1047.0
# 135     2013      1    1     826.0             715       71.0    1136.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336759  2013      9   30    2207.0            2140       27.0    2257.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 85                 941       30.0      UA    1111  N37456    EWR  MCO
# 96                 850       49.0      MQ    3737  N508MQ    EWR  ORD
# 119                830      137.0      MQ    4576  N531MQ    LGA  CLT
# 135               1045       51.0      AA     443  N3GVAA    JFK  MIA
# 151               1950      851.0      MQ    3944  N942MQ    JFK  BWI
# ...                ...        ...     ...     ...     ...    ...  ...
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336759            2250        7.0      MQ    3660  N532MQ    LGA  BNA
# 336760            2242       57.0      EV    4672  N12145    EWR  STL
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute             time_hour
# 85         145.0       937     6      45  2013-01-01T11:00:00Z
# 96         148.0       719     7      10  2013-01-01T12:00:00Z
# 119        118.0       544     6      30  2013-01-01T11:00:00Z
# 135        160.0      1089     7      15  2013-01-01T12:00:00Z
# 151         41.0       184    18      35  2013-01-01T23:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336757      50.0       301    18      45  2013-09-30T22:00:00Z
# 336759      97.0       764    21      40  2013-10-01T01:00:00Z
# 336760     120.0       872    20      59  2013-10-01T00:00:00Z
# 336762     318.0      2565    21      13  2013-10-01T01:00:00Z
# 336763     123.0       944    20       1  2013-10-01T00:00:00Z
#
# [54347 rows x 19 columns]

# %%
## note that in filtered_by_delay there are some observations that have delay time less than 25 mins.
filtered_by_delay[filtered_by_delay.dep_delay <25]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 152     2013      1    1     848.0             851       -3.0    1155.0
# 733     2013      1    1    1952.0            1930       22.0    2358.0
# 1067    2013      1    2     900.0             859        1.0    1146.0
# 1642    2013      1    2    1921.0            1909       12.0    2143.0
# 1672    2013      1    2    1954.0            2000       -6.0    2241.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336605  2013      9   30    1852.0            1900       -8.0    2100.0
# 336644  2013      9   30    1928.0            1932       -4.0    2137.0
# 336659  2013      9   30    1939.0            1950      -11.0    2112.0
# 336677  2013      9   30    2000.0            2007       -7.0    2142.0
# 336707  2013      9   30    2031.0            2040       -9.0    2228.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 152               1136       19.0      UA    1741  N27724    EWR  JAC
# 733               2207        NaN      EV    4333  N11194    EWR  TUL
# 1067              1144        2.0      UA    1741  N23708    EWR  JAC
# 1642              2115       28.0      EV    4543  N34110    EWR  DSM
# 1672              2216       25.0      9E    4033  N8516C    LGA  TYS
# ...                ...        ...     ...     ...     ...    ...  ...
# 336605            2104       -4.0      9E    3445  N909XJ    LGA  DSM
# 336644            2143       -6.0      EV    4361  N18556    EWR  TYS
# 336659            2141      -29.0      EV    5038  N713EV    LGA  BHM
# 336677            2202      -20.0      EV    4543  N11194    EWR  DSM
# 336707            2300      -32.0      9E    4033  N8924B    LGA  TYS
#
#         air_time  distance  hour  minute             time_hour
# 152        275.0      1874     8      51  2013-01-01T13:00:00Z
# 733          NaN      1215    19      30  2013-01-02T00:00:00Z
# 1067       258.0      1874     8      59  2013-01-02T13:00:00Z
# 1642       180.0      1017    19       9  2013-01-03T00:00:00Z
# 1672       121.0       647    20       0  2013-01-03T01:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336605     137.0      1031    19       0  2013-09-30T23:00:00Z
# 336644      82.0       631    19      32  2013-09-30T23:00:00Z
# 336659     112.0       866    19      50  2013-09-30T23:00:00Z
# 336677     138.0      1017    20       7  2013-10-01T00:00:00Z
# 336707      86.0       647    20      40  2013-10-01T00:00:00Z
#
# [1379 rows x 19 columns]

# %%
## when we use groupby method pandas returns a groupby object
grouped = flights.groupby('dest')

# %%
## note that result is a dataframe
print(type(grouped.get_group('CAE')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
grouped.get_group('CAE')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 2511    2013      1    3    1843.0            1828       15.0    2102.0
# 5000    2013      1    6    1839.0            1836        3.0    2118.0
# 8654    2013      1   10    1827.0            1828       -1.0    2031.0
# 11163   2013      1   13    1958.0            1836       82.0    2231.0
# 14837   2013      1   17    2004.0            1828       96.0    2227.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 322546  2013      9   15    1807.0            1810       -3.0    2044.0
# 326428  2013      9   19    1809.0            1757       12.0    1955.0
# 329047  2013      9   22    1805.0            1810       -5.0    2021.0
# 333052  2013      9   26    1911.0            1745       86.0    2124.0
# 335621  2013      9   29    1858.0            1900       -2.0    2059.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 2511              2026       36.0      EV    4410  N21537    EWR  CAE
# 5000              2031       47.0      EV    4437  N15912    EWR  CAE
# 8654              2026        5.0      EV    4410  N18557    EWR  CAE
# 11163             2031      120.0      EV    4437  N16571    EWR  CAE
# 14837             2026      121.0      EV    4410  N13553    EWR  CAE
# ...                ...        ...     ...     ...     ...    ...  ...
# 322546            2007       37.0      EV    4278  N11547    EWR  CAE
# 326428            1954        1.0      EV    4410  N11192    EWR  CAE
# 329047            2007       14.0      EV    4278  N16951    EWR  CAE
# 333052            1942      102.0      EV    4410  N12900    EWR  CAE
# 335621            2057        2.0      EV    4278  N14542    EWR  CAE
#
#         air_time  distance  hour  minute             time_hour
# 2511       105.0       602    18      28  2013-01-03T23:00:00Z
# 5000       115.0       602    18      36  2013-01-06T23:00:00Z
# 8654        89.0       602    18      28  2013-01-10T23:00:00Z
# 11163       98.0       602    18      36  2013-01-13T23:00:00Z
# 14837      116.0       602    18      28  2013-01-17T23:00:00Z
# ...          ...       ...   ...     ...                   ...
# 322546      89.0       602    18      10  2013-09-15T22:00:00Z
# 326428      79.0       602    17      57  2013-09-19T21:00:00Z
# 329047      98.0       602    18      10  2013-09-22T22:00:00Z
# 333052      85.0       602    17      45  2013-09-26T21:00:00Z
# 335621      84.0       602    19       0  2013-09-29T23:00:00Z
#
# [116 rows x 19 columns]

# %%
## now we can check the average dep_delay time for this group is bigger than 25 or not
grouped.get_group('CAE').dep_delay.mean() > 25
# Out:
# True

# %%
## the average dep_delay is more than 25
## therefore observations that belong to 'CAE' group will be returned after we filter the dataframe

# %%
## in fact we know from our previous work that the destinations with more than 25 mins 
## delay are ['JAC', 'TUL', 'DSM', 'OKC', 'TYS', 'BHM', 'CAE' ]
## therefore the filtering above is equivalent to the code below but more convenient
flights[flights.dest.isin(['JAC', 'TUL', 'DSM', 'OKC', 'TYS', 'BHM', 'CAE' ])]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 152     2013      1    1     848.0             851       -3.0    1155.0
# 733     2013      1    1    1952.0            1930       22.0    2358.0
# 742     2013      1    1    2000.0            1930       30.0    2255.0
# 754     2013      1    1    2016.0            1930       46.0       NaN
# 803     2013      1    1    2119.0            1930      109.0    2358.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336659  2013      9   30    1939.0            1950      -11.0    2112.0
# 336677  2013      9   30    2000.0            2007       -7.0    2142.0
# 336707  2013      9   30    2031.0            2040       -9.0    2228.0
# 336731  2013      9   30    2059.0            2003       56.0    2311.0
# 336734  2013      9   30    2104.0            2019       45.0    2304.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 152               1136       19.0      UA    1741  N27724    EWR  JAC
# 733               2207        NaN      EV    4333  N11194    EWR  TUL
# 742               2140       75.0      EV    4361  N12567    EWR  TYS
# 754               2220        NaN      EV    4204  N14168    EWR  OKC
# 803               2136      142.0      EV    4543  N13123    EWR  DSM
# ...                ...        ...     ...     ...     ...    ...  ...
# 336659            2141      -29.0      EV    5038  N713EV    LGA  BHM
# 336677            2202      -20.0      EV    4543  N11194    EWR  DSM
# 336707            2300      -32.0      9E    4033  N8924B    LGA  TYS
# 336731            2237       34.0      EV    4204  N11127    EWR  OKC
# 336734            2240       24.0      EV    4333  N11109    EWR  TUL
#
#         air_time  distance  hour  minute             time_hour
# 152        275.0      1874     8      51  2013-01-01T13:00:00Z
# 733          NaN      1215    19      30  2013-01-02T00:00:00Z
# 742        138.0       631    19      30  2013-01-02T00:00:00Z
# 754          NaN      1325    19      30  2013-01-02T00:00:00Z
# 803        200.0      1017    19      30  2013-01-02T00:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336659     112.0       866    19      50  2013-09-30T23:00:00Z
# 336677     138.0      1017    20       7  2013-10-01T00:00:00Z
# 336707      86.0       647    20      40  2013-10-01T00:00:00Z
# 336731     166.0      1325    20       3  2013-10-01T00:00:00Z
# 336734     154.0      1215    20      19  2013-10-01T00:00:00Z
#
# [2299 rows x 19 columns]

# %% [markdown]
# ## Transform Method

# %% [markdown]
# Pandas.Series objects supports vectorized operations.

# %%
flights['speed_per_hour'] = flights.distance/flights.air_time*60

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour  speed_per_hour
# 0      1400     5      15  2013-01-01T10:00:00Z      370.044053
# 1      1416     5      29  2013-01-01T10:00:00Z      374.273128
# 2      1089     5      40  2013-01-01T10:00:00Z      408.375000
# 3      1576     5      45  2013-01-01T10:00:00Z      516.721311
# 4       762     6       0  2013-01-01T11:00:00Z      394.137931

# %% [markdown]
# Now let's compare each observation with the mean of their destination group.

# %%
def speed_func(group):
  return group - group.mean()

# %%
flights['speed_dif_from_group'] = flights.groupby('dest')['speed_per_hour'].transform(speed_func)
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1             830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2             850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 3            1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 4             837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute             time_hour speed_per_hour  \
# 0      1400     5      15  2013-01-01T10:00:00Z     370.044053
# 1      1416     5      29  2013-01-01T10:00:00Z     374.273128
# 2      1089     5      40  2013-01-01T10:00:00Z     408.375000
# 3      1576     5      45  2013-01-01T10:00:00Z     516.721311
# 4       762     6       0  2013-01-01T11:00:00Z     394.137931
#
#    speed_dif_from_group
# 0            -59.107943
# 1            -54.878868
# 2            -21.458001
# 3             29.549375
# 4            -11.044173
#
# [5 rows x 21 columns]

# %% [markdown]
# __Transforming Missing Values with Group Mean__

# %%
def my_filling_func(group):
  m = group.mean()
  if np.isnan(m):
    return -9999
  else:
    return group.fillna(m)

# %%
flights['air_time'] = flights.groupby('dest')['air_time'].transform(my_filling_func)
flights.tail(3)

# %% [markdown]
# another transform example

# %%
def relative_contribution_to_total_delay(group):
  return group/group.sum()

# %%
flights['dep_delay_relative_transform'] = flights.groupby(['origin', 'dest', 'month', 'day'])['dep_delay'].transform(relative_contribution_to_total_delay) 
flights.head(13)

# %% [markdown]
# # Lab

# %% [markdown]
# Using the flights dataframe, display all the flights

# %% [markdown]
# 1. Had an arrival delay of two or more hours.
#
# 2. Flew to Houston (IAH or HOU)
#
# 3. Were operated by American, Delta
#
# 4. How many values are missing in `dep_time`?
#
# 5. Sort `flight` to find fastest flight.

# %% [markdown]
# answer the following questions
#
# 6. Which flights travelled the shortest?
#
# 7. When do the first and last flights leave each day?
#
# 8. When there is a missing value in `dep_time` then this is an indication of canceled flight. Find the number of cancelled flights for each (`carrier`, `origin`) combination.
#
# 9. Which carrier has the worst `dep_delay`s?
#
# 10. Which plane (`tailnum`) has the worst on-time record?
#
# 11. For each plane, count the number of flights before the first delay of greater than 1 hour.
