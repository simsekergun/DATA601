# %% [markdown]
# <a href="https://colab.research.google.com/github/simsekergun/DATA601/blob/main/HW/HW04Spring2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA601 Homework Assignment 4
#
# Due Date: 04/14/2022 by 23:59 pm

# %% [markdown]
# # Set-up

# %% [markdown]
# 1. Rename this file using your first name, e.g. Ergun_HW04.ipynb
# 2. Make sure that your notebook works! To do this, please choose "Restart Kernel and Run All Cells" before you submit.
# 3. Do not forget to save your notebook before you submit!
# 4. Run the cell below to import pandas and read the datasets

# %%
## Don't change the names of the datasets.
import pandas as pd
dmv_hs =pd.read_csv('https://raw.githubusercontent.com/simsekergun/DATA601/main/Datasets/hs_dmv.csv', index_col= 0)
maryland_hs = pd.read_csv('https://raw.githubusercontent.com/simsekergun/DATA601/main/Datasets/hs_md.csv',index_col = 0
)

# %% [markdown]
# ## Question-1 <font color='red'>(3 points)</font>

# %% [markdown]
# __Tasks:__
#
# - Change the column names according to the map given below.
# - Name the new dataframe with new column names as `maryland`
# - check your new dataframe, e.g. <code> maryland.head(3) </code>

# %% [markdown]
# 'School Name': 'school_name',
#
# 'State Name [Public School] Latest available year': 'state_name',
#
# 'Lowest Grade Offered [Public School] 2018-19': 'lowest_grade_offered'
#
# 'Highest Grade Offered [Public School] 2018-19': 'highest_grade_offered'
#
# 'Total Students All Grades (Excludes AE) [Public School] 2018-19': 'total_students_all_grades'
#
# 'Free and Reduced Lunch Students [Public School] 2018-19': 'free_and_reduced_lunch_students'
#
# 'Reduced-price Lunch Eligible Students [Public School] 2018-19': 'reduced-price_lunch_eligible_students'
#
# 'Latitude [Public School] 2018-19': 'latitude'
#
# 'Longitude [Public School] 2018-19': 'longitude'
#
# 'Magnet School [Public School] 2018-19': 'magnet_school'
#
# 'Charter School [Public School] 2018-19': 'charter_school'
#
# 'Shared Time School [Public School] 2018-19': 'shared_time_school'
#
# 'Urban-centric Locale [Public School] 2018-19']: 'urban_centric_locale'

# %%
## Answer

# %% [markdown]
# In case you couldn't solve the first problem, then remove the #'s in the cell below and run it to continue.

# %%
#maryland = pd.read_csv('https://raw.githubusercontent.com/simsekergun/DATA601/main/Datasets/hs_data_with_new_column_names.csv', 
#                       index_col = 0)
#maryland.head(3)

# %% [markdown]
# ## Question 2 <font color='red'>(3 points)</font>

# %% [markdown]
# __Tasks__
#
# - Drop the column `state_name` from the data frame `maryland`. Make sure that the changes are reflected in the dataframe `maryland` without re-assigning.
#
# - Change name of the column 'state_name_latest_available_year' to 'state_name' in `dmv_hs` dataframe. Make sure that you make the changes in the original dataframe `dmv_hs`.
#
# - Resulting dataframes should look like below.

# %% [markdown]
# ![Screen Shot 2021-10-09 at 9.17.50 AM.png](data:image/png;base64,...)

# %%
## Answer

# %%
## Answer

# %% [markdown]
# ## Question 3 <font color='red'>(3 points)</font>

# %% [markdown]
# a) How many different states are there in the `dmv_highschool` dataset? Make sure you check before jump into a conclusion.

# %%
## answer

# %%
##

# %% [markdown]
# b) Standardize the state names in `dmv_hs` dataframe. That is: First letter capital, all others lower case. e.g. DisTrict oF Columbia --> District Of Columbia. Double check your answer.
#
# - Make sure that you changed the column in the original dataframe.
#
# - After your solution `dmv_hs` should look like below.

# %% [markdown]
# ![Screen Shot 2021-10-09 at 9.23.17 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Question 4 <font color='red'>(3 points)</font>

# %% [markdown]
# (a) How many different locations (latitude, longitude) are there in this dataframe?

# %%
## Answer

# %% [markdown]
# (b) Note that some locations are repeating in the dataframe. Find out which location(latitude, longitude) is repeating and find out why these high schools entered as a separate rows in this dataset.
#
# [Hint-1](https://www.carrollk12.org/schools/high/alt/about/Pages/gatewayhigh.aspx)
#
# [Hint-2](https://www.carrollk12.org/schools/high/alt/about/Pages/fss.aspx)

# %%
## Answer

# %% [markdown]
# Comments:

# %% [markdown]
# ## Question 5 <font color='red'>(4 points)</font>

# %% [markdown]
# For the problems below we will be using the dataframe `maryland_big` which is a combination of `maryland` and `dmv_hs` datasets. Note that in this dataframe in addition to columns of `maryland` dataframe we have extra information like `county_name` and `location_zip`.

# %%
## Don't forget to run this cell!!
## Don't change anything in this cell

maryland_big = pd.read_csv('https://raw.githubusercontent.com/simsekergun/DATA601/main/Datasets/hs_md_combined.csv')
print(maryland_big.shape)
maryland_big.head()
# Out:
# (204, 21)
#                               school_name state_name lowest_grade_offered  \
# 0                           ABERDEEN HIGH   Maryland            9th Grade
# 1      ACADEMY OF HEALTH SCIENCES AT PGCC   Maryland            9th Grade
# 2  ACHIEVEMENT ACADEMY @ HARBOR CITY HIGH   Maryland            9th Grade
# 3                    ALBERT EINSTEIN HIGH   Maryland            9th Grade
# 4                           ALLEGANY HIGH   Maryland            9th Grade
#
#   highest_grade_offered  total_students_all_grades  \
# 0            12th Grade                       1458
# 1            12th Grade                        518
# 2            12th Grade                        411
# 3            12th Grade                       1746
# 4            12th Grade                        721
#
#    free_and_reduced_lunch_students reduced-price_lunch_eligible_students  \
# 0                              661                                   124
# ...

# %% [markdown]
# __Task__
#
# - For each county find the average number of students.
# - Sort the result in an descending order and display.

# %%
## your answer is here

# %% [markdown]
# ## Question 6 <font color='red'>(4 points)</font>

# %% [markdown]
# For each school find the ratio of `free_and_reduced_lunch_students` to the total number of students who are in the same __zipcode__ with this school. Record these values in a new column named `ratio` and display the first 3 rows after adding this new column. Suppose in high school _A_ there are 13 students eligible for free and reduced lunch and the zipcode of the school is 20001. If there is total of 200 students in the zipcode 20001 then for High School A your code should return 13/200. Hint: We used similar method at the data transformations class.

# %%
## Answer
