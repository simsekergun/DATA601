# %% [markdown]
# ## Introduction to Pandas
# ### What's pandas?
#  - Pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. <br>
#  - Pandas is part of the Anaconda distribution and can be installed with Anaconda (e.g. <code> conda install pandas </code>) or via pip (<code> pip install pandas</code>) <br>
#  - When working with tabular data, such as data stored in spreadsheets or databases, pandas is the right tool (assuming not so large files). <br>
# pandas help us to explore, clean, and process our data. <br>
#  - In pandas, a data table is called a DataFrame.  <br>
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/01_table_dataframe.svg" width="600">
#
#  - pandas supports the integration with many file formats or data sources out of the box (csv, excel, sql, json, parquet,…). Importing data from each of these data sources is provided by function with the prefix <span style="color: red;">read_*</span>. Similarly, the <span style="color: red;">to_*</span> methods are used to store data <br> [e.g. <code> sales = pd.read_csv("sales_data.csv" </code>) ] <br>
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/02_io_readwrite.svg" width="800">
#
# Before working with different datasets, let's learn the basics.

# %% [markdown]
# <b> Note: </b> Make sure that you have/installed pandas and openpyxl before we proceed <br>.
# Once again, you can use the terminal <br>
# <code> conda install pandas </code> <br>
# and <br>
# <code> conda install -c anaconda openpyxl </code>
# <br>
# If you don't use conda, then <br>
# <code> pip install pandas  </code> <br>
# <code> pip install openpyxl </code>
# <br>
# <b> Note: </b> We will work on time series / date functionality later. <br>
# In the meantime, you can start learning about them at <br>
# https://pandas.pydata.org/docs/user_guide/timeseries.html <br>
# https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Object Creation

# %%
# Creating a Series by passing a list of values, 
# letting pandas create a default integer index:
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:
dates = pd.date_range('20190101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Let's use dates as our index

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195
# 2019-01-06  0.351456  1.533327  1.761936  0.176647

# %%
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
# The columns of the resulting DataFrame have different dtypes.
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ### Viewing Data

# %%
# Here is how to view the top rows of the frame:
df.head()
# Out:
#                    A         B         C         D
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195

# %%
# or
df.head(3)
# Out:
#                    A         B         C         D
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415

# %%
# Here is how to view the bottom rows of the frame:
df.tail(2)
# Out:
#                    A         B         C         D
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195
# 2019-01-06  0.351456  1.533327  1.761936  0.176647

# %%
# Display the index
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Display the columns
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# DataFrame.values gives a NumPy representation of the underlying data
df.values
# Out:
# array([[-1.60244117,  1.0853052 ,  0.74962417, -0.37126793],
#        [ 0.50302262,  0.82567918, -1.08965773, -0.55409644],
#        [-0.89700507,  2.7846948 ,  0.84048639,  0.70641488],
#        [-0.8754481 ,  0.18679625, -0.62380403, -0.48510946],
#        [-1.01545866, -0.34266074,  0.83524672,  1.31419502],
#        [ 0.35145569,  1.53332727,  1.7619365 ,  0.17664708]])

# %%
# note that DataFrame.values does not include the index or column labels in the output.

# %%
# describe() shows a quick statistic summary of your data:
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.589312  1.012190  0.412305  0.131131
# std    0.832204  1.092738  1.060841  0.752909
# min   -1.602441 -0.342661 -1.089658 -0.554096
# 25%   -0.985845  0.346517 -0.280447 -0.456649
# 50%   -0.886227  0.955492  0.792435 -0.097310
# 75%    0.044730  1.421322  0.839176  0.573973
# max    0.503023  2.784695  1.761936  1.314195

# %%
# Transposing your data:
df.T
# Out:
#    2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  2019-01-06
# A   -1.602441    0.503023   -0.897005   -0.875448   -1.015459    0.351456
# B    1.085305    0.825679    2.784695    0.186796   -0.342661    1.533327
# C    0.749624   -1.089658    0.840486   -0.623804    0.835247    1.761936
# D   -0.371268   -0.554096    0.706415   -0.485109    1.314195    0.176647

# %%
# Sorting by an axis:
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2019-01-01 -0.371268  0.749624  1.085305 -1.602441
# 2019-01-02 -0.554096 -1.089658  0.825679  0.503023
# 2019-01-03  0.706415  0.840486  2.784695 -0.897005
# 2019-01-04 -0.485109 -0.623804  0.186796 -0.875448
# 2019-01-05  1.314195  0.835247 -0.342661 -1.015459
# 2019-01-06  0.176647  1.761936  1.533327  0.351456

# %%
# Sorting by values
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268
# 2019-01-06  0.351456  1.533327  1.761936  0.176647
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415

# %% [markdown]
# ### SELECTION

# %%
# Selecting a single column, which yields a Series, equivalent to df.A:
df['A']
# Out:
# 2019-01-01   -1.602441
# 2019-01-02    0.503023
# 2019-01-03   -0.897005
# 2019-01-04   -0.875448
# 2019-01-05   -1.015459
# 2019-01-06    0.351456
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2019-01-01   -1.602441
# 2019-01-02    0.503023
# 2019-01-03   -0.897005
# 2019-01-04   -0.875448
# 2019-01-05   -1.015459
# 2019-01-06    0.351456
# Freq: D, Name: A, dtype: float64

# %%
# Selecting via [], which slices the rows.
df[0:3]
# Out:
#                    A         B         C         D
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415

# %%
df['20190102':'20190104']
# Out:
#                    A         B         C         D
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109

# %% [markdown]
# #### Selection by Label

# %%
# For getting a cross section using a label:
df.loc[dates[0]]
# Out:
# A   -1.602441
# B    1.085305
# C    0.749624
# D   -0.371268
# Name: 2019-01-01 00:00:00, dtype: float64

# %%
# Selecting on a multi-axis by label:
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2019-01-01 -1.602441  1.085305
# 2019-01-02  0.503023  0.825679
# 2019-01-03 -0.897005  2.784695
# 2019-01-04 -0.875448  0.186796
# 2019-01-05 -1.015459 -0.342661
# 2019-01-06  0.351456  1.533327

# %%
# Showing label slicing, both endpoints are included:
df.loc['20190102':'20190104', ['A', 'B']]
# Out:
#                    A         B
# 2019-01-02  0.503023  0.825679
# 2019-01-03 -0.897005  2.784695
# 2019-01-04 -0.875448  0.186796

# %%
# Reduction in the dimensions of the returned object:
df.loc['20190102', ['A', 'B']]
# Out:
# A    0.503023
# B    0.825679
# Name: 2019-01-02 00:00:00, dtype: float64

# %%
# For getting a scalar value:
df.loc[dates[0], 'A']
# Out:
# -1.602441170910617

# %%
# For getting fast access to a scalar (equivalent to the prior method):
df.at[dates[0], 'A']
# Out:
# -1.602441170910617

# %% [markdown]
# #### Selection by Position

# %%
# Select via the position of the passed integers:
df.iloc[3]
# Out:
# A   -0.875448
# B    0.186796
# C   -0.623804
# D   -0.485109
# Name: 2019-01-04 00:00:00, dtype: float64

# %%
# By integer slices, acting similar to numpy/python:
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2019-01-04 -0.875448  0.186796
# 2019-01-05 -1.015459 -0.342661

# %%
# By lists of integer position locations, similar to the numpy/python style:
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2019-01-02  0.503023 -1.089658
# 2019-01-03 -0.897005  0.840486
# 2019-01-05 -1.015459  0.835247

# %%
# For slicing rows explicitly:
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415

# %%
# For slicing columns explicitly:
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2019-01-01  1.085305  0.749624
# 2019-01-02  0.825679 -1.089658
# 2019-01-03  2.784695  0.840486
# 2019-01-04  0.186796 -0.623804
# 2019-01-05 -0.342661  0.835247
# 2019-01-06  1.533327  1.761936

# %%
# For getting a value explicitly:
df.iloc[1, 1]
# Out:
# 0.8256791782112872

# %%
# For getting fast access to a scalar (equivalent to the prior method):
# loc: label based indexing
# iloc: position based indexing
# at: works with individuals. label based
# iat: works with individuals. position based
# 
df.iat[1, 1]
# Out:
# 0.8256791782112872

# %% [markdown]
# ### Boolean Indexing

# %%
# Using a single column’s values to select data.
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096
# 2019-01-06  0.351456  1.533327  1.761936  0.176647

# %%
# Selecting values from a DataFrame where a boolean condition is met
df[df > 0]
# Out:
#                    A         B         C         D
# 2019-01-01       NaN  1.085305  0.749624       NaN
# 2019-01-02  0.503023  0.825679       NaN       NaN
# 2019-01-03       NaN  2.784695  0.840486  0.706415
# 2019-01-04       NaN  0.186796       NaN       NaN
# 2019-01-05       NaN       NaN  0.835247  1.314195
# 2019-01-06  0.351456  1.533327  1.761936  0.176647

# %%
# Using the isin() method for filtering:
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268    one
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096    one
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415    two
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109  three
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195   four
# 2019-01-06  0.351456  1.533327  1.761936  0.176647  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415   two
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195  four

# %% [markdown]
# ###  Setting

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20190102', periods=6))
s1
# Out:
# 2019-01-02    1
# 2019-01-03    2
# 2019-01-04    3
# 2019-01-05    4
# 2019-01-06    5
# 2019-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
# note that our original index starts at the 1st day of the month
# however s1 starts at the 2nd day of the month
df
# Out:
#                    A         B         C         D    F
# 2019-01-01 -1.602441  1.085305  0.749624 -0.371268  NaN
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415  2.0
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109  3.0
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195  4.0
# 2019-01-06  0.351456  1.533327  1.761936  0.176647  5.0

# %%
# Setting values by label:
df.at[dates[0], 'A'] = 0
# or df.iat[0, 1] = 0
df
# Out:
#                    A         B         C         D    F
# 2019-01-01  0.000000  1.085305  0.749624 -0.371268  NaN
# 2019-01-02  0.503023  0.825679 -1.089658 -0.554096  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  0.706415  2.0
# 2019-01-04 -0.875448  0.186796 -0.623804 -0.485109  3.0
# 2019-01-05 -1.015459 -0.342661  0.835247  1.314195  4.0
# 2019-01-06  0.351456  1.533327  1.761936  0.176647  5.0

# %%
# Setting by assigning with a NumPy array:
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D    F
# 2019-01-01  0.000000  1.085305  0.749624  5  NaN
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  5  2.0
# 2019-01-04 -0.875448  0.186796 -0.623804  5  3.0
# 2019-01-05 -1.015459 -0.342661  0.835247  5  4.0
# 2019-01-06  0.351456  1.533327  1.761936  5  5.0

# %% [markdown]
# ## MISSING DATA
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %%
# Reindexing allows you to change/add/delete the index on a specified axis. 
# This returns a copy of the data.
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1
# Out:
#                    A         B         C  D    F   E
# 2019-01-01  0.000000  1.085305  0.749624  5  NaN NaN
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0 NaN
# 2019-01-03 -0.897005  2.784695  0.840486  5  2.0 NaN
# 2019-01-04 -0.875448  0.186796 -0.623804  5  3.0 NaN

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2019-01-01  0.000000  1.085305  0.749624  5  NaN  1.0
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  5  2.0  NaN
# 2019-01-04 -0.875448  0.186796 -0.623804  5  3.0  NaN

# %%
# To drop any rows that have missing data.
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0  1.0

# %%
# Filling missing data.
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2019-01-01  0.000000  1.085305  0.749624  5  5.0  1.0
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  5  2.0  5.0
# 2019-01-04 -0.875448  0.186796 -0.623804  5  3.0  5.0

# %%
# To get the boolean mask where values are nan.
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2019-01-01  False  False  False  False   True  False
# 2019-01-02  False  False  False  False  False  False
# 2019-01-03  False  False  False  False  False   True
# 2019-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Statistics

# %%
# Performing a descriptive statistic:
# average of columns
df.mean()
# Out:
# A   -0.322239
# B    1.012190
# C    0.412305
# D    5.000000
# F    3.000000
# dtype: float64

# %%
# average of rows (simply by setting axis to 1)
df.mean(1)
# Out:
# 2019-01-01    1.708732
# 2019-01-02    1.247809
# 2019-01-03    1.945635
# 2019-01-04    1.337509
# 2019-01-05    1.695425
# 2019-01-06    2.729344
# Freq: D, dtype: float64

# %%
# Operating with objects that have different dimensionality and need alignment. 
# In addition, pandas automatically broadcasts along the specified dimension.
dates = pd.date_range('20190101', periods=6)
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2019-01-01    NaN
# 2019-01-02    NaN
# 2019-01-03    1.0
# 2019-01-04    3.0
# 2019-01-05    5.0
# 2019-01-06    NaN
# Freq: D, dtype: float64

# %%
# Above, when we shift index, 1st month becomes 3 month, 2nd month becomes 4th, etc.
# but since we don't have 7th and 8th months in our index, when they are shifted,
# 1st and 2nd elements become NaN

# %%
# dataframe.sub: Subtraction of dataframe and other, element-wise (binary operator sub).
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2019-01-01       NaN       NaN       NaN  NaN  NaN
# 2019-01-02       NaN       NaN       NaN  NaN  NaN
# 2019-01-03 -1.897005  1.784695 -0.159514  4.0  1.0
# 2019-01-04 -3.875448 -2.813204 -3.623804  2.0  0.0
# 2019-01-05 -6.015459 -5.342661 -4.164753  0.0 -1.0
# 2019-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %%
df
# Out:
#                    A         B         C  D    F
# 2019-01-01  0.000000  1.085305  0.749624  5  NaN
# 2019-01-02  0.503023  0.825679 -1.089658  5  1.0
# 2019-01-03 -0.897005  2.784695  0.840486  5  2.0
# 2019-01-04 -0.875448  0.186796 -0.623804  5  3.0
# 2019-01-05 -1.015459 -0.342661  0.835247  5  4.0
# 2019-01-06  0.351456  1.533327  1.761936  5  5.0

# %%
# dataframe.cumsum returns cumulative sum over a DataFrame or Series axis.
#
# cumulative sum over columns
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2019-01-01  0.000000  1.085305  0.749624   5   NaN
# 2019-01-02  0.503023  1.910984 -0.340034  10   1.0
# 2019-01-03 -0.393982  4.695679  0.500453  15   3.0
# 2019-01-04 -1.269431  4.882475 -0.123351  20   6.0
# 2019-01-05 -2.284889  4.539815  0.711896  25  10.0
# 2019-01-06 -1.933434  6.073142  2.473832  30  15.0

# %%
# finding range manually is also easy
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.518481
# B    3.127356
# C    2.851594
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## MERGING
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.

# %% [markdown]
# #### CONCAT

# %%
df = pd.DataFrame(np.random.randn(6, 6))
df
# Out:
#           0         1         2         3         4         5
# 0  0.122575 -0.194884 -0.298372 -0.113745  0.462031 -1.639570
# 1 -1.196892 -1.468972  0.025460 -1.491095  0.366549 -1.923014
# 2  0.351090 -0.907090  2.881327 -0.235757  0.837280 -1.625965
# 3 -0.784128 -0.171704  0.385104 -0.412256  0.547938  0.020435
# 4  2.928417  1.069938  0.855756  1.577579  0.580966  0.828410
# 5 -0.924166  0.906125 -0.989821  0.751811 -0.470987 -1.531281

# %%
# break it into pieces
pieces = [df[:2], df[4:6]]
pieces
# Out:
# [          0         1         2         3         4         5
#  0  0.122575 -0.194884 -0.298372 -0.113745  0.462031 -1.639570
#  1 -1.196892 -1.468972  0.025460 -1.491095  0.366549 -1.923014,
#            0         1         2         3         4         5
#  4  2.928417  1.069938  0.855756  1.577579  0.580966  0.828410
#  5 -0.924166  0.906125 -0.989821  0.751811 -0.470987 -1.531281]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3         4         5
# 0  0.122575 -0.194884 -0.298372 -0.113745  0.462031 -1.639570
# 1 -1.196892 -1.468972  0.025460 -1.491095  0.366549 -1.923014
# 4  2.928417  1.069938  0.855756  1.577579  0.580966  0.828410
# 5 -0.924166  0.906125 -0.989821  0.751811 -0.470987 -1.531281

# %% [markdown]
# #### JOIN
# SQL style merges

# %%
width = pd.DataFrame({'Model': ['Levis501', 'Levis550'], 'Width': [30, 32]})
width
# Out:
#       Model  Width
# 0  Levis501     30
# 1  Levis550     32

# %%
length = pd.DataFrame({'Model': ['Levis501', 'Levis550'], 'Length': [28, 34]})
length
# Out:
#       Model  Length
# 0  Levis501      28
# 1  Levis550      34

# %%
pd.merge(width, length, on='Model')
# Out:
#       Model  Width  Length
# 0  Levis501     30      28
# 1  Levis550     32      34

# %% [markdown]
# ### APPEND

# %%
# Append rows to a dataframe
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.215385  2.012416 -0.674822  0.196134
# 1  0.465235  1.006335 -0.897718  0.501591
# 2 -0.382298  1.997144  0.292837 -0.979337
# 3 -0.795342  0.788394 -1.152757 -1.662110
# 4  1.650114 -0.388831 -0.525035  0.914271
# 5 -0.221009 -0.644659 -1.200352 -0.898873
# 6 -0.437748  0.240508  0.319455  0.253330
# 7  0.901403  1.640059 -0.209378 -0.717349

# %%
# Let's add 4th row to the end 
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.215385  2.012416 -0.674822  0.196134
# 1  0.465235  1.006335 -0.897718  0.501591
# 2 -0.382298  1.997144  0.292837 -0.979337
# 3 -0.795342  0.788394 -1.152757 -1.662110
# 4  1.650114 -0.388831 -0.525035  0.914271
# 5 -0.221009 -0.644659 -1.200352 -0.898873
# 6 -0.437748  0.240508  0.319455  0.253330
# 7  0.901403  1.640059 -0.209378 -0.717349
# 8 -0.795342  0.788394 -1.152757 -1.662110

# %% [markdown]
# ## GROUPING

# %%
# By “group by” we are referring to a process involving one or more of the following steps:
# (a) Splitting the data into groups based on some criteria
# (b) Applying a function to each group independently
# (c) Combining the results into a data structure

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                         'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three',
                         'two', 'two', 'one', 'three'],
                   'C': np.random.randn(8),
                   'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  0.810694 -0.439390
# 1  bar    one  1.214784 -0.066822
# 2  foo    two  0.142232  0.233133
# 3  bar  three -1.300278  0.122822
# 4  foo    two -1.833379  0.350255
# 5  bar    two  0.109615 -0.111229
# 6  foo    one  0.291031 -0.212079
# 7  foo  three  1.374528 -0.303806

# %%
# Grouping and then applying the sum() function to the resulting groups.
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.024122 -0.055229
# foo  0.785107 -0.371887

# %%
# Grouping by multiple columns forms a hierarchical index,
# and again we can apply the sum function.
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.214784 -0.066822
#     three -1.300278  0.122822
#     two    0.109615 -0.111229
# foo one    1.101725 -0.651470
#     three  1.374528 -0.303806
#     two   -1.691147  0.583389

# %% [markdown]
# ## Reshaping

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))
print(tuples)
# Out:
# [('bar', 'one'), ('bar', 'two'), ('baz', 'one'), ('baz', 'two'), ('foo', 'one'), ('foo', 'two'), ('qux', 'one'), ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.066728 -0.229220
#       two     0.852109 -0.216804
# baz   one    -0.924069 -1.299537
#       two    -0.241673  0.612730
# foo   one    -0.409100  0.602468
#       two    -0.006013  0.459864
# qux   one     1.922854  0.224384
#       two    -1.597423 -0.713932

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.066728 -0.229220
#       two     0.852109 -0.216804
# baz   one    -0.924069 -1.299537
#       two    -0.241673  0.612730

# %% [markdown]
# #### STACK

# %%
# The stack() method “compresses” a level in the DataFrame’s columns.
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.066728
#                B   -0.229220
#        two     A    0.852109
#                B   -0.216804
# baz    one     A   -0.924069
#                B   -1.299537
#        two     A   -0.241673
#                B    0.612730
# dtype: float64

# %%
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), 
# the inverse operation of stack() is unstack(), which by default unstacks the last level:
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.066728 -0.229220
#       two     0.852109 -0.216804
# baz   one    -0.924069 -1.299537
#       two    -0.241673  0.612730

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.066728  0.852109
#       B -0.229220 -0.216804
# baz   A -0.924069 -0.241673
#       B -1.299537  0.612730

# %%
# Remember df2
df2
# Out:
#                      A         B
# first second
# bar   one     0.066728 -0.229220
#       two     0.852109 -0.216804
# baz   one    -0.924069 -1.299537
#       two    -0.241673  0.612730

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.066728 -0.924069
#        B -0.229220 -1.299537
# two    A  0.852109 -0.241673
#        B -0.216804  0.612730

# %% [markdown]
# ### PIVOT TABLES

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                   'B': ['A', 'B', 'C'] * 4,
                   'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.404110 -0.162747
# 1     one  B  foo -0.363499  0.290523
# 2     two  C  foo -1.231403  0.384918
# 3   three  A  bar  0.369030  2.255434
# 4     one  B  bar  0.619211  0.098821
# 5     one  C  bar -0.622422  0.061612
# 6     two  A  foo  1.010363  2.888265
# 7   three  B  foo -0.508140 -1.161562
# 8     one  C  foo  0.019359 -0.188258
# 9     one  A  bar -0.956210  1.314583
# 10    two  B  bar  1.177452 -0.321312
# 11  three  C  bar -0.438578 -0.174555

# %%
# We can produce pivot tables from this data very easily:
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.956210 -1.404110
#       B  0.619211 -0.363499
#       C -0.622422  0.019359
# three A  0.369030       NaN
#       B       NaN -0.508140
#       C -0.438578       NaN
# two   A       NaN  1.010363
#       B  1.177452       NaN
#       C       NaN -1.231403

# %%
# Example 2
df = pd.DataFrame({
    'A': ['A','B','AB','0']*3,
    'B': np.random.randn(12),
    'C': ['Male','Male','Male','Female','Female','Female']*2,
    'D': np.random.randint(1940,2001,12)})  
df['B'] = df['B'].apply(lambda x: 1 if np.random.randn() > 0 else -1)

# %%
df
# Out:
#      A  B       C     D
# 0    A -1    Male  1955
# 1    B -1    Male  1956
# 2   AB  1    Male  1992
# 3    0  1  Female  1989
# 4    A  1  Female  1955
# 5    B  1  Female  1941
# 6   AB  1    Male  1987
# 7    0  1    Male  1947
# 8    A  1    Male  1978
# 9    B -1  Female  1975
# 10  AB  1  Female  1989
# 11   0 -1  Female  1999

# %%
pd.pivot_table(df,values='D',index=['A','B'], columns=['C'])
# Out:
# C      Female    Male
# A  B
# 0  -1  1999.0     NaN
#     1  1989.0  1947.0
# A  -1     NaN  1955.0
#     1  1955.0  1978.0
# AB  1  1989.0  1989.5
# B  -1  1975.0  1956.0
#     1  1941.0     NaN

# %% [markdown]
# ## GETTING DATA IN/OUT

# %% [markdown]
# ### CSV

# %%
# Writing to a csv file
df.to_csv('foo.csv')

# %%
# Reading from a csv file.
pd.read_csv('foo.csv')
# Out:
#     Unnamed: 0   A  B       C     D
# 0            0   A -1    Male  1955
# 1            1   B -1    Male  1956
# 2            2  AB  1    Male  1992
# 3            3   0  1  Female  1989
# 4            4   A  1  Female  1955
# 5            5   B  1  Female  1941
# 6            6  AB  1    Male  1987
# 7            7   0  1    Male  1947
# 8            8   A  1    Male  1978
# 9            9   B -1  Female  1975
# 10          10  AB  1  Female  1989
# 11          11   0 -1  Female  1999

# %% [markdown]
# ### Excel

# %%
# Writing to an excel file.
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
# Reading from an excel file.
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0   A  B       C     D
# 0            0   A -1    Male  1955
# 1            1   B -1    Male  1956
# 2            2  AB  1    Male  1992
# 3            3   0  1  Female  1989
# 4            4   A  1  Female  1955
# 5            5   B  1  Female  1941
# 6            6  AB  1    Male  1987
# 7            7   0  1    Male  1947
# 8            8   A  1    Male  1978
# 9            9   B -1  Female  1975
# 10          10  AB  1  Female  1989
# 11          11   0 -1  Female  1999
