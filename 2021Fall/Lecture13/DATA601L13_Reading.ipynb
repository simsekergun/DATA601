# %% [markdown]
# [Programming Paradigms - Youtube Video](https://www.youtube.com/watch?v=Wt4FPjkCNaU&ab_channel=Craig%27n%27Dave)
#
# [Imperative vs Declarative Programming - Youtube Video](https://www.youtube.com/watch?v=yOBBkIJBEL8&ab_channel=TadasPetra)
#
# - What is a programming paradigm?
#
# - Explain the differences of low level and high level programming languages.
#
# - Explain the differences between imperative and declarative languages.
#
#
# [Object Oriented Programming - PY4e](https://www.py4e.com/lessons/Objects#)
#
# [Classes and Instances - Corey Schafer](https://www.youtube.com/watch?v=ZDa-Z5JzLYM&list=PL-osiE80TeTsqhIuOqKhwlXsIBIdSeYtc&index=1&t=2s&ab_channel=CoreySchafer)
#
# - Why do we need classes?
#
# - What is an object?
#
# - How do you create an object?
#
# - What is method and attrite in the context of OOP?
#
# - What is a class variable?
#
# - What is inheritance and why we would use it?
#
# - What is the method that help us to instantiate a class?
#
# - What is 'self'?
