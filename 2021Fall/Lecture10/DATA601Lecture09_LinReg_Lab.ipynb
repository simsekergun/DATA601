# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

## CHEAT SHEET
##  Train/Test splitting example 
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
#
##  Linear Regression Fitting example
# model = LinearRegression()
# model.fit(X_train, Y_train)
#
## prediction example
# y_test_predict = model.predict(X_test)
#
## model evaluation
# rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
# r2 = r2_score(Y_train, y_train_predict)

# %% [markdown]
# ### Advertising Dataset
# - The Advertising dataset consists of the sales of that product in 200 different markets, along with advertising budgets for the product in each of those markets for three different media: TV, radio, and newspaper.
# - It is not possible for our client to directly increase sales of the product, but they can control the advertising expenditure in each of the three media.
# - Therefore, if we determine that there is an association between advertising and sales, then we can instruct our client to adjust advertising budgets, thereby indirectly increasing sales.

# %%
# get the data
advertising = pd.read_csv('https://raw.githubusercontent.com/simsekergun/DATA601/main/2021Fall/datasets/Advertising.csv', index_col=0)

# %% [markdown]
# ### Step 0
# Get familiar with your dataset. <br>

# %% [markdown]
# ### Step 1
#  <b>1.1</b> Build a linear regression model to estimate the Sales using the TV advertisement. <br>
#  Use 80% of the dataset for training and 20% for the testing, and calculate RMSE and R$^2$. <br>

# %%
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = advertising['TV']
Y = advertising['Sales']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

# %%
pd.DataFrame(X_train)
# Out:
#         TV
# 160  131.7
# 63   239.3
# 167   17.9
# 46   175.1
# 24   228.3
# ..     ...
# 74   129.4
# 145   96.2
# 119  125.7
# 190   18.7
# 100  135.2
#
# [160 rows x 1 columns]

# %%
##  Linear Regression Fitting example
model = LinearRegression()
model.fit(pd.DataFrame(X_train), pd.DataFrame(Y_train))
#
## prediction example
y_test_predict = model.predict(pd.DataFrame(X_test))
#
## model evaluation
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
print(rmse,r2)
# Out:
# 3.5467773583968802 0.4990784791512455

# %%
advertising.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.scatter(X_test.values, Y_test.values,color='b')
plt.scatter(X_test.values, y_test_predict,color='r')
plt.show()

# %%
X = advertising['Radio']
Y = advertising['Sales']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

##  Linear Regression Fitting example
model = LinearRegression()
model.fit(pd.DataFrame(X_train), pd.DataFrame(Y_train))
#
## prediction example
y_test_predict = model.predict(pd.DataFrame(X_test))
#
## model evaluation
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
print(rmse,r2)
# Out:
# 3.8298072392346834 0.415942416631467

# %%
X = advertising['Newspaper']
Y = advertising['Sales']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

##  Linear Regression Fitting example
model = LinearRegression()
model.fit(pd.DataFrame(X_train), pd.DataFrame(Y_train))
#
## prediction example
y_test_predict = model.predict(pd.DataFrame(X_test))
#
## model evaluation
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
print(rmse,r2)
# Out:
# 4.843055813227019 0.06601310238902325

# %%
X = advertising[['TV', 'Radio','Newspaper']]
Y = advertising['Sales']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

##  Linear Regression Fitting example
model = LinearRegression()
model.fit(pd.DataFrame(X_train), pd.DataFrame(Y_train))
#
## prediction example
y_test_predict = model.predict(pd.DataFrame(X_test))
#
## model evaluation
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)
print(rmse,r2)
# Out:
# 1.5971739466799182 0.8984204533332627

# %% [markdown]
#  <br>
#  <b>1.2</b> Build a linear regression model to estimate the Sales using the Radio advertisement. <br>
#  Use 80% of the dataset for training and 20% for the testing, and calculate RMSE and R$^2$.<br>
#  <br>
# <b>1.3</b> Build a linear regression model to estimate the Sales using the Newspaper advertisement. <br>
#  Use 80% of the dataset for training and 20% for the testing, and calculate RMSE and R$^2$. <br>
# <br>
# Try to answer following questions:
# 1. Is there a relationship between ads and sales?
# 2. How strong is that relationship?
# 3. Which ad types contribute to sales?
# 4. What is the effect of each ad type of sales?
# 5. How many sales should we expect if we spend \\$400k on TV ads? (Note that all the numbers in the Advertising data is normalized by 1000, e.g. TV = 150 means they spent \\$150k on TV advertising and they sold 10,000 - 20,000 devices.)

# %%
advertising.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# ### Step 2
# Build a linear regression model to estimate Sales using
#  - TV & Radio <br>
# again use 80% of the dataset for training and 20% for the testing, and calculate RMSE and R$^2$. <br>
# visualize $\hat{y} = \beta_0+\beta_1*x_{TV} + \beta_2*x_{Radio}$ the surface. In the same plot show training data as well

# %% [markdown]
# ### Step 3
# Build a linear regression model to estimate Sales using
# - TV & Radio & Newspaper <br>
# Again use 80% of the dataset for training and 20% for the testing, and calculate RMSE and R$^2$
