# %% [markdown]
# [Working With Time Series - Python Data Science](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html)

# %% [markdown]
# Notes for your reading:
#
# - What is timestamp, time intervals and time deltas?
#
# - What are the modules to handle time data in Python?
#
# - How to create a 'Timestamp' object in 'pandas'?
#
# - What are the advantages of using 'DatetimeIndex' in 'pandas'?
#
# - How to create regular date sequences in 'pandas'?
#
# - How do we use 'Frequencies and offsets' to create regular data sequences?
#
# - What is resampling, shifting and windowing?
