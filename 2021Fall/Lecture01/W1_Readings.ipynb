# %% [markdown]
# # Introduction to Data Science
#
# [IBM: Data Science Introduction](https://www.ibm.com/cloud/learn/data-science-introduction): Read sections: What is data science?, Data Science Tools.
#
# __Questions to ask as yourself as you are reading:__
#
# - What are the core skills a data scientists should have?
#
# - What are the steps of data science procedure?
#
# [Data Scientist: The Sexiest Job of the 21st Century](https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century):
#
# __Questions to ask as yourself as you are reading:__
#
# - The article is written in 2012 and they mention there is no university program offering data science degree. Roughly how many universities do offer data science degree right now in US?
#
# - According to this article, what does a data scientist do in a business?
#
#
# [Interview: Dean Abbott, Co-Founder and Chief Data Scientist at Smarter HQ](https://www.youtube.com/watch?v=83aDDHiIFg0&ab_channel=BerkeleyHaas): From 2:15 to 6:22 on Unpacking the term data science.
#
# __Questions to ask yourself as you are watching:__
#
# - He talks about how data science is very similar to statistical learning, machine learning etc., To him, what are the things that distinguishes data science from these fields?

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# [Shell Commands in IPython](https://jakevdp.github.io/PythonDataScienceHandbook/01.05-ipython-and-shell-commands.html)
#
# [Python: Variables](https://jakevdp.github.io/WhirlwindTourOfPython/03-semantics-variables.html)
#
# [Python: Operators](https://jakevdp.github.io/WhirlwindTourOfPython/04-semantics-operators.html)
#
# [Python: Functions](https://jakevdp.github.io/WhirlwindTourOfPython/08-defining-functions.html)
